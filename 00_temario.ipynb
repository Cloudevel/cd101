# %% [markdown]
# [![https://cloudevel.com/](https://cloudevel.com/es-mx/media/cloudevel-fondo-twitter.png)](https://cloudevel.com)

# %% [markdown]
# # Introducción a GNU/Linux
# 1. Introducción.
#     * Objetivos y alcances del taller.
#     * Material didáctico.
#     * ¿Qué es GNU/Linux?
#     * Instalación de la VM del taller.
# * Inicio de un sistema GNU/Linux.
#     * UEFI y Secure Mode.
#     * El arrancador _GRUB_.
#     * El kernel de Linux.
#     * Módulos.
#     * Gestión de módulos.
#     * Manipulación de prámetros del kernel con _sysctl_.
#     * Inicio con _init_ y _systemd_.
#     * La línea de comandos, terminales y el shell.
# * Ayuda.
#     * _man_.
#     * _apropos_.
#     * _which_.
#     * _whatis_.
# * El editor _vim_.
# * Filtros y pipes.
#     * Entrada y salida estándar.
#     * Filtros más utilizados.
#     * Enrutamiento de flujos con pipes.
# * Usuarios y grupos.
#     * El usuario root.
#     * Gestión de usuarios y grupos.
#     * Uitilerías.
#     * Escalamiento de permisos.
# * Funcionamiento y estructura de archivos.
#     * Conceptos básicos.
#     * Estructura de archivos de un sistema GNU/Linux.
#     * Fornatos de particiones.
#     * Sistemas de archivos especiales.
#     * Montado de volúmenes.
#     * Monitoreo y mantenimiento de sistemas de archivos.
#     * Introducción a _LVM_.
# * Manejo de directorios y archivos.
#     * Operaciones básicas con directorios y archivos.
#     * Propietarios y permisos.
#     * Búsqueda de archivos.
# * Particiones y volúmenes de archivos.
#      * Dispositivos de almacenamiento.
#      * Particionamiento de disco.
#      * Formatos de partic=ones.
#      * Estructura y pariciones de disco.
# * Introducción a redes.
#     * Protocolos básicos de TCP/IP.
#     * Fundamentos de redes TCP/IP.
#     * Interfaces.
#     * Archivos de configuración.
#     * El servicio _NetworkManager_.
#     * Utilerías.
#     * Secure shell.
#     * Transferencia y descarga de archivos.
# * Paquetes de archivos y de software.
#     * Compresión y descompresión de archivos.
#     * Instalación de software.
# * Procesos, trabajos y temporizadores.
#     * Conceptos básicos.
#     * Listado y monitoreo de procesos y recursos.
#     * Señales a procesos.
#     * Sucesión de procesos.
#     * Prioridades.
#     * Trabajos.
#     * Temporizadores.
# * Introducción a Bash scripting.
#     * Listado y definición de variables de entorno.
#     * Archivos de configuración de entorno.
#     * Scripts simples.
# * Gestión de servicios con systemd.
#     * Funcionamiento de systemd.
#     * Comandos de gestión de servicios.
#     * Puesta enmarcha de servicios comunes.
#     * Creación de un servicio propio.
# * Seguridad básica.
#     * Integridad de archivos.
#     * Firewall.
# * Terminales gráficas y VNC.
#     * El servidor X.
#     * Entornos gráficos.
#     * _VNC_.
# * Virtualización y contenedores.
#     * Conceptos básicos.
#     * Virtualización.
#     * Contenedores.
#     * Subsistema para Linux de Windows.

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017.</p>
