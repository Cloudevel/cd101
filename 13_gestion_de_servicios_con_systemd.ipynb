# %% [markdown]
# [![cloudevel](Imagenes/cloudevel.png)](https://cloudevel.com)

# %% [markdown]
# # Gestión de servicios con _systemd_.

# %% [markdown]
# ## El directorio _/lib/systemd/system_.
#
# En este directorio sene encuentran todos los servicios qiue gestiona systemd.

# %%
ls sudo /lib/systemd/system
# Out:
# ls: no se puede acceder a sudo: No existe el fichero o el directorio
# /lib/systemd/system:
# auditd.service
# autovt@.service
# basic.target
# basic.target.wants
# blk-availability.service
# bluetooth.target
# brandbot.path
# brandbot.service
# chrony-dnssrv@.service
# chrony-dnssrv@.timer
# chronyd.service
# chrony-wait.service
# console-getty.service
# console-shell.service
# container-getty@.service
# cpupower.service
# crond.service
# cryptsetup-pre.target
# cryptsetup.target
# ctrl-alt-del.target
# dbus-org.freedesktop.hostname1.service
# dbus-org.freedesktop.import1.service
# dbus-org.freedesktop.locale1.service
# dbus-org.freedesktop.login1.service
# dbus-org.freedesktop.machine1.service
# dbus-org.freedesktop.timedate1.service
# dbus.service
# dbus.socket
# dbus.target.wants
# debug-shell.service
# default.target
# default.target.wants
# dev-hugepages.mount
# dev-mqueue.mount
# dm-event.service
# dm-event.socket
# dracut-cmdline.service
# dracut-initqueue.service
# dracut-mount.service
# dracut-pre-mount.service
# dracut-pre-pivot.service
# dracut-pre-trigger.service
# dracut-pre-udev.service
# dracut-shutdown.service
# ebtables.service
# emergency.service
# emergency.target
# final.target
# firewalld.service
# fstrim.service
# fstrim.timer
# getty-pre.target
# getty@.service
# getty.target
# graphical.target
# graphical.target.wants
# halt-local.service
# halt.target
# halt.target.wants
# hibernate.target
# htcacheclean.service
# httpd.service
# hybrid-sleep.target
# initrd-cleanup.service
# initrd-fs.target
# initrd-parse-etc.service
# initrd-root-fs.target
# initrd-switch-root.service
# initrd-switch-root.target
# initrd-switch-root.target.wants
# initrd.target
# initrd.target.wants
# initrd-udevadm-cleanup-db.service
# iprdump.service
# iprinit.service
# iprupdate.service
# iprutils.target
# irqbalance.service
# jupyter.service
# kdump.service
# kexec.target
# kexec.target.wants
# kmod-static-nodes.service
# local-fs-pre.target
# local-fs.target
# local-fs.target.wants
# lvm2-lvmetad.service
# lvm2-lvmetad.socket
# lvm2-lvmpolld.service
# lvm2-lvmpolld.socket
# lvm2-monitor.service
# lvm2-pvscan@.service
# machine.slice
# machines.target
# mariadb.service
# messagebus.service
# microcode.service
# multi-user.target
# multi-user.target.wants
# NetworkManager-dispatcher.service
# NetworkManager.service
# NetworkManager-wait-online.service
# network-online.target
# network-pre.target
# network.target
# nss-lookup.target
# nss-user-lookup.target
# paths.target
# plymouth-halt.service
# plymouth-kexec.service
# plymouth-poweroff.service
# plymouth-quit.service
# plymouth-quit-wait.service
# plymouth-read-write.service
# plymouth-reboot.service
# plymouth-start.service
# plymouth-switch-root.service
# polkit.service
# postfix.service
# poweroff.target
# poweroff.target.wants
# printer.target
# proc-sys-fs-binfmt_misc.automount
# proc-sys-fs-binfmt_misc.mount
# quotaon.service
# rc-local.service
# rdisc.service
# reboot.target
# reboot.target.wants
# remote-cryptsetup.target
# remote-fs-pre.target
# remote-fs.target
# rescue.service
# rescue.target
# rescue.target.wants
# rhel-autorelabel-mark.service
# rhel-autorelabel.service
# rhel-configure.service
# rhel-dmesg.service
# rhel-domainname.service
# rhel-import-state.service
# rhel-loadmodules.service
# rhel-readonly.service
# rpcbind.target
# rsyncd.service
# rsyncd@.service
# rsyncd.socket
# rsyslog.service
# runlevel0.target
# runlevel1.target
# runlevel1.target.wants
# runlevel2.target
# runlevel2.target.wants
# runlevel3.target
# runlevel3.target.wants
# runlevel4.target
# runlevel4.target.wants
# runlevel5.target
# runlevel5.target.wants
# runlevel6.target
# selinux-policy-migrate-local-changes@.service
# serial-getty@.service
# shutdown.target
# shutdown.target.wants
# sigpwr.target
# sleep.target
# -.slice
# slices.target
# smartcard.target
# sockets.target
# sockets.target.wants
# sound.target
# sshd-keygen.service
# sshd.service
# sshd@.service
# sshd.socket
# suspend.target
# svnserve.service
# swap.target
# sys-fs-fuse-connections.mount
# sysinit.target
# sysinit.target.wants
# sys-kernel-config.mount
# sys-kernel-debug.mount
# syslog.socket
# syslog.target.wants
# systemd-ask-password-console.path
# systemd-ask-password-console.service
# systemd-ask-password-plymouth.path
# systemd-ask-password-plymouth.service
# systemd-ask-password-wall.path
# systemd-ask-password-wall.service
# systemd-backlight@.service
# systemd-binfmt.service
# systemd-bootchart.service
# systemd-firstboot.service
# systemd-fsck-root.service
# systemd-fsck@.service
# systemd-halt.service
# systemd-hibernate-resume@.service
# systemd-hibernate.service
# systemd-hostnamed.service
# systemd-hwdb-update.service
# systemd-hybrid-sleep.service
# systemd-importd.service
# systemd-initctl.service
# systemd-initctl.socket
# systemd-journal-catalog-update.service
# systemd-journald.service
# systemd-journald.socket
# systemd-journal-flush.service
# systemd-kexec.service
# systemd-localed.service
# systemd-logind.service
# systemd-machined.service
# systemd-machine-id-commit.service
# systemd-modules-load.service
# systemd-nspawn@.service
# systemd-poweroff.service
# systemd-quotacheck.service
# systemd-random-seed.service
# systemd-readahead-collect.service
# systemd-readahead-done.service
# systemd-readahead-done.timer
# systemd-readahead-drop.service
# systemd-readahead-replay.service
# systemd-reboot.service
# systemd-remount-fs.service
# systemd-rfkill@.service
# systemd-shutdownd.service
# systemd-shutdownd.socket
# systemd-suspend.service
# systemd-sysctl.service
# systemd-timedated.service
# systemd-tmpfiles-clean.service
# systemd-tmpfiles-clean.timer
# systemd-tmpfiles-setup-dev.service
# systemd-tmpfiles-setup.service
# systemd-udevd-control.socket
# systemd-udevd-kernel.socket
# systemd-udevd.service
# systemd-udev-settle.service
# systemd-udev-trigger.service
# systemd-update-done.service
# systemd-update-utmp-runlevel.service
# systemd-update-utmp.service
# systemd-user-sessions.service
# systemd-vconsole-setup.service
# system.slice
# system-update.target
# tcsd.service
# teamd@.service
# timers.target
# timers.target.wants
# time-sync.target
# tmp.mount
# tuned.service
# umount.target
# user.slice
# wpa_supplicant.service
# : 2

# %%
sudo ls /lib/systemd/system/ju*
# Out:
# ls: no se puede acceder a sudo: No existe el fichero o el directorio
# /lib/systemd/system/jupyter.service
# : 2

# %%
cat /lib/systemd/system/runlevel5.target
# Out:
# #  This file is part of systemd.
# #
# #  systemd is free software; you can redistribute it and/or modify it
# #  under the terms of the GNU Lesser General Public License as published by
# #  the Free Software Foundation; either version 2.1 of the License, or
# #  (at your option) any later version.
#
# [Unit]
# Description=Graphical Interface
# Documentation=man:systemd.special(7)
# Requires=multi-user.target
# Wants=display-manager.service
# Conflicts=rescue.service rescue.target
# After=multi-user.target rescue.service rescue.target display-manager.service
# AllowIsolate=yes

# %%
cat /lib/systemd/system/runlevel5.target.wants
# Out:
# cat: /lib/systemd/system/runlevel5.target.wants: Es un directorio
# : 1

# %%
cat /lib/systemd/system/multi-user.target
# Out:
# #  This file is part of systemd.
# #
# #  systemd is free software; you can redistribute it and/or modify it
# #  under the terms of the GNU Lesser General Public License as published by
# #  the Free Software Foundation; either version 2.1 of the License, or
# #  (at your option) any later version.
#
# [Unit]
# Description=Multi-User System
# Documentation=man:systemd.special(7)
# Requires=basic.target
# Conflicts=rescue.service rescue.target
# After=basic.target rescue.service rescue.target
# AllowIsolate=yes

# %%
cat /lib/systemd/system/jupyter.service
# Out:
# [Unit]
# Description=Jupyter Notebook
#
# [Service]
# Type=simple
# PIDFile=/run/jupyter.pid
# ExecStart=/usr/bin/jupyter notebook --ip='*'
# User=oi
# Group=oi
# WorkingDirectory=/opt/cloudevel/
# Restart=always
# RestartSec=10
# #KillMode=mixed
#
# [Install]
# WantedBy=multi-user.target

# %% [markdown]
# ## Runlevels, targets y servicios.

# %% [markdown]
# ## Comandos de gestión de servicios.
# ### ```systemctl```.
# Es el comando de gestión de los servicios de systemd
#
#
# ```
# systemctl <acción> <servicio>
#
# ```
#
# #### Acciones.
#
# * ```enable```
# * ```disable```
# * ```start```
# * ```status```
# * ```stop```

# %% [markdown]
# ```sudo systemctl status```

# %%
systemctl status httpd.service
# Out:
# ● httpd.service - The Apache HTTP Server
#    Loaded: loaded (/usr/lib/systemd/system/httpd.service; enabled; vendor preset: disabled)
#    Active: active (running) since vie 2019-03-15 11:54:20 PDT; 3h 33min ago
#      Docs: man:httpd(8)
#            man:apachectl(8)
#  Main PID: 990 (httpd)
#    Status: "Total requests: 0; Current requests/sec: 0; Current traffic:   0 B/sec"
#    CGroup: /system.slice/httpd.service
#            ├─ 990 /usr/sbin/httpd -DFOREGROUND
#            ├─1190 /usr/sbin/httpd -DFOREGROUND
#            ├─1191 /usr/sbin/httpd -DFOREGROUND
#            ├─1192 /usr/sbin/httpd -DFOREGROUND
#            ├─1193 /usr/sbin/httpd -DFOREGROUND
#            └─1195 /usr/sbin/httpd -DFOREGROUND
#
# mar 15 11:54:20 cloudevel.localdomain systemd[1]: Starting The Apache HTTP Se...
# mar 15 11:54:20 cloudevel.localdomain httpd[990]: AH00558: httpd: Could not r...
# mar 15 11:54:20 cloudevel.localdomain systemd[1]: Started The Apache HTTP Ser...
# Hint: Some lines were ellipsized, use -l to show in full.

# %%
sudo systemctl stop httpd

# %%
sudo systemctl status httpd
# Out:
# ● httpd.service - The Apache HTTP Server
#    Loaded: loaded (/usr/lib/systemd/system/httpd.service; enabled; vendor preset: disabled)
#    Active: inactive (dead) since vie 2019-03-15 15:30:21 PDT; 18s ago
#      Docs: man:httpd(8)
#            man:apachectl(8)
#   Process: 2138 ExecStop=/bin/kill -WINCH ${MAINPID} (code=exited, status=0/SUCCESS)
#   Process: 990 ExecStart=/usr/sbin/httpd $OPTIONS -DFOREGROUND (code=exited, status=0/SUCCESS)
#  Main PID: 990 (code=exited, status=0/SUCCESS)
#    Status: "Total requests: 2; Current requests/sec: 0; Current traffic:   0 B/sec"
#
# mar 15 11:54:20 cloudevel.localdomain systemd[1]: Starting The Apache HTTP Se...
# mar 15 11:54:20 cloudevel.localdomain httpd[990]: AH00558: httpd: Could not r...
# mar 15 11:54:20 cloudevel.localdomain systemd[1]: Started The Apache HTTP Ser...
# mar 15 15:30:20 cloudevel.localdomain systemd[1]: Stopping The Apache HTTP Se...
# mar 15 15:30:21 cloudevel.localdomain systemd[1]: Stopped The Apache HTTP Ser...
# Hint: Some lines were ellipsized, use -l to show in full.
# : 3

# %%
sudo systemctl start httpd

# %%
sudo systemctl status httpd
# Out:
# ● httpd.service - The Apache HTTP Server
#    Loaded: loaded (/usr/lib/systemd/system/httpd.service; enabled; vendor preset: disabled)
#    Active: active (running) since vie 2019-03-15 15:31:00 PDT; 15s ago
#      Docs: man:httpd(8)
#            man:apachectl(8)
#   Process: 2138 ExecStop=/bin/kill -WINCH ${MAINPID} (code=exited, status=0/SUCCESS)
#  Main PID: 2151 (httpd)
#    Status: "Total requests: 1; Current requests/sec: 0.111; Current traffic: 113 B/sec"
#    CGroup: /system.slice/httpd.service
#            ├─2151 /usr/sbin/httpd -DFOREGROUND
#            ├─2153 /usr/sbin/httpd -DFOREGROUND
#            ├─2154 /usr/sbin/httpd -DFOREGROUND
#            ├─2155 /usr/sbin/httpd -DFOREGROUND
#            ├─2156 /usr/sbin/httpd -DFOREGROUND
#            ├─2157 /usr/sbin/httpd -DFOREGROUND
#            └─2158 /usr/sbin/httpd -DFOREGROUND
#
# mar 15 15:30:59 cloudevel.localdomain systemd[1]: Starting The Apache HTTP Se...
# mar 15 15:30:59 cloudevel.localdomain httpd[2151]: AH00558: httpd: Could not ...
# mar 15 15:31:00 cloudevel.localdomain systemd[1]: Started The Apache HTTP Ser...
# Hint: Some lines were ellipsized, use -l to show in full.

# %% [markdown]
# ###  ```service```.
#
# El comando *service* es el comando usado por System V para la gestión de servicios.
#
# Algunas distribuciones de GNU/Linux enmascaran *systemd* y traducen sus sinstrucciones mediante *service*.
#
# ```
# service <servicio> <acción>
# ```

# %%
sudo yum update -y
# Out:
# Complementos cargados:fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: repos-tx.psychz.net
#  * epel: mirror.compevo.com
#  * extras: mirror.rackspace.com
#  * updates: mirror.atlantic.net
# Resolviendo dependencias
# --> Ejecutando prueba de transacción
# ---> Paquete GeoIP.x86_64 0:1.5.0-11.el7 debe ser actualizado
# ---> Paquete GeoIP.x86_64 0:1.5.0-13.el7 debe ser una actualización
# ---> Paquete NetworkManager.x86_64 1:1.10.2-16.el7_5 debe ser actualizado
# ---> Paquete NetworkManager.x86_64 1:1.12.0-8.el7_6 debe ser una actualización
# ---> Paquete NetworkManager-libnm.x86_64 1:1.10.2-16.el7_5 debe ser actualizado
# ---> Paquete NetworkManager-libnm.x86_64 1:1.12.0-8.el7_6 debe ser una actualización
# ---> Paquete NetworkManager-team.x86_64 1:1.10.2-16.el7_5 debe ser actualizado
# ---> Paquete NetworkManager-team.x86_64 1:1.12.0-8.el7_6 debe ser una actualización
# ---> Paquete NetworkManager-tui.x86_64 1:1.10.2-16.el7_5 debe ser actualizado
# ---> Paquete NetworkManager-tui.x86_64 1:1.12.0-8.el7_6 debe ser una actualización
# ---> Paquete NetworkManager-wifi.x86_64 1:1.10.2-16.el7_5 debe ser actualizado
# ---> Paquete NetworkManager-wifi.x86_64 1:1.12.0-8.el7_6 debe ser una actualización
# ---> Paquete alsa-lib.x86_64 0:1.1.4.1-2.el7 debe ser actualizado
# ---> Paquete alsa-lib.x86_64 0:1.1.6-2.el7 debe ser una actualización
# ---> Paquete audit.x86_64 0:2.8.1-3.el7 debe ser actualizado
# ---> Paquete audit.x86_64 0:2.8.4-4.el7 debe ser una actualización
# ---> Paquete audit-libs.x86_64 0:2.8.1-3.el7 debe ser actualizado
# ---> Paquete audit-libs.x86_64 0:2.8.4-4.el7 debe ser una actualización
# ---> Paquete bash.x86_64 0:4.2.46-30.el7 debe ser actualizado
# ---> Paquete bash.x86_64 0:4.2.46-31.el7 debe ser una actualización
# ---> Paquete bind-libs-lite.x86_64 32:9.9.4-61.el7 debe ser actualizado
# ---> Paquete bind-libs-lite.x86_64 32:9.9.4-73.el7_6 debe ser una actualización
# ---> Paquete bind-license.noarch 32:9.9.4-61.el7 debe ser actualizado
# ---> Paquete bind-license.noarch 32:9.9.4-73.el7_6 debe ser una actualización
# ---> Paquete binutils.x86_64 0:2.27-28.base.el7_5.1 debe ser actualizado
# ---> Paquete binutils.x86_64 0:2.27-34.base.el7 debe ser una actualización
# ---> Paquete bison.x86_64 0:3.0.4-1.el7 debe ser actualizado
# ---> Paquete bison.x86_64 0:3.0.4-2.el7 debe ser una actualización
# ---> Paquete cairo.x86_64 0:1.14.8-2.el7 debe ser actualizado
# ---> Paquete cairo.x86_64 0:1.15.12-3.el7 debe ser una actualización
# --> Procesando dependencias: libGL.so.1()(64bit) para el paquete: cairo-1.15.12-3.el7.x86_64
# --> Procesando dependencias: libEGL.so.1()(64bit) para el paquete: cairo-1.15.12-3.el7.x86_64
# ---> Paquete cairo-devel.x86_64 0:1.14.8-2.el7 debe ser actualizado
# ---> Paquete cairo-devel.x86_64 0:1.15.12-3.el7 debe ser una actualización
# ---> Paquete centos-release.x86_64 0:7-5.1804.el7.centos.2 debe ser actualizado
# ---> Paquete centos-release.x86_64 0:7-6.1810.2.el7.centos debe ser una actualización
# ---> Paquete coreutils.x86_64 0:8.22-21.el7 debe ser actualizado
# ---> Paquete coreutils.x86_64 0:8.22-23.el7 debe ser una actualización
# ---> Paquete cpp.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete cpp.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete cronie.x86_64 0:1.4.11-19.el7 debe ser actualizado
# ---> Paquete cronie.x86_64 0:1.4.11-20.el7_6 debe ser una actualización
# ---> Paquete cronie-anacron.x86_64 0:1.4.11-19.el7 debe ser actualizado
# ---> Paquete cronie-anacron.x86_64 0:1.4.11-20.el7_6 debe ser una actualización
# ---> Paquete cryptsetup-libs.x86_64 0:1.7.4-4.el7 debe ser actualizado
# ---> Paquete cryptsetup-libs.x86_64 0:2.0.3-3.el7 debe ser una actualización
# --> Procesando dependencias: libjson-c.so.2()(64bit) para el paquete: cryptsetup-libs-2.0.3-3.el7.x86_64
# ---> Paquete curl.x86_64 0:7.29.0-46.el7 debe ser actualizado
# ---> Paquete curl.x86_64 0:7.29.0-51.el7 debe ser una actualización
# ---> Paquete dbus.x86_64 1:1.10.24-7.el7 debe ser actualizado
# ---> Paquete dbus.x86_64 1:1.10.24-12.el7 debe ser una actualización
# ---> Paquete dbus-libs.x86_64 1:1.10.24-7.el7 debe ser actualizado
# ---> Paquete dbus-libs.x86_64 1:1.10.24-12.el7 debe ser una actualización
# ---> Paquete device-mapper.x86_64 7:1.02.146-4.el7 debe ser actualizado
# ---> Paquete device-mapper.x86_64 7:1.02.149-10.el7_6.3 debe ser una actualización
# ---> Paquete device-mapper-event.x86_64 7:1.02.146-4.el7 debe ser actualizado
# ---> Paquete device-mapper-event.x86_64 7:1.02.149-10.el7_6.3 debe ser una actualización
# ---> Paquete device-mapper-event-libs.x86_64 7:1.02.146-4.el7 debe ser actualizado
# ---> Paquete device-mapper-event-libs.x86_64 7:1.02.149-10.el7_6.3 debe ser una actualización
# ---> Paquete device-mapper-libs.x86_64 7:1.02.146-4.el7 debe ser actualizado
# ---> Paquete device-mapper-libs.x86_64 7:1.02.149-10.el7_6.3 debe ser una actualización
# ---> Paquete dmidecode.x86_64 1:3.0-5.el7 debe ser actualizado
# ---> Paquete dmidecode.x86_64 1:3.1-2.el7 debe ser una actualización
# ---> Paquete dracut.x86_64 0:033-535.el7 debe ser actualizado
# ---> Paquete dracut.x86_64 0:033-554.el7 debe ser una actualización
# ---> Paquete dracut-config-rescue.x86_64 0:033-535.el7 debe ser actualizado
# ---> Paquete dracut-config-rescue.x86_64 0:033-554.el7 debe ser una actualización
# ---> Paquete dracut-network.x86_64 0:033-535.el7 debe ser actualizado
# ---> Paquete dracut-network.x86_64 0:033-554.el7 debe ser una actualización
# ---> Paquete dyninst.x86_64 0:9.3.1-1.el7 debe ser actualizado
# ---> Paquete dyninst.x86_64 0:9.3.1-2.el7 debe ser una actualización
# ---> Paquete e2fsprogs.x86_64 0:1.42.9-12.el7_5 debe ser actualizado
# ---> Paquete e2fsprogs.x86_64 0:1.42.9-13.el7 debe ser una actualización
# ---> Paquete e2fsprogs-libs.x86_64 0:1.42.9-12.el7_5 debe ser actualizado
# ---> Paquete e2fsprogs-libs.x86_64 0:1.42.9-13.el7 debe ser una actualización
# ---> Paquete efivar-libs.x86_64 0:31-4.el7 debe ser actualizado
# ---> Paquete efivar-libs.x86_64 0:36-11.el7_6.1 debe ser una actualización
# ---> Paquete elfutils.x86_64 0:0.170-4.el7 debe ser actualizado
# ---> Paquete elfutils.x86_64 0:0.172-2.el7 debe ser una actualización
# ---> Paquete elfutils-default-yama-scope.noarch 0:0.170-4.el7 debe ser actualizado
# ---> Paquete elfutils-default-yama-scope.noarch 0:0.172-2.el7 debe ser una actualización
# ---> Paquete elfutils-libelf.x86_64 0:0.170-4.el7 debe ser actualizado
# ---> Paquete elfutils-libelf.x86_64 0:0.172-2.el7 debe ser una actualización
# ---> Paquete elfutils-libs.x86_64 0:0.170-4.el7 debe ser actualizado
# ---> Paquete elfutils-libs.x86_64 0:0.172-2.el7 debe ser una actualización
# ---> Paquete emacs-filesystem.noarch 1:24.3-20.el7_4 debe ser actualizado
# ---> Paquete emacs-filesystem.noarch 1:24.3-22.el7 debe ser una actualización
# ---> Paquete ethtool.x86_64 2:4.8-7.el7 debe ser actualizado
# ---> Paquete ethtool.x86_64 2:4.8-9.el7 debe ser una actualización
# ---> Paquete file.x86_64 0:5.11-33.el7 debe ser actualizado
# ---> Paquete file.x86_64 0:5.11-35.el7 debe ser una actualización
# ---> Paquete file-devel.x86_64 0:5.11-33.el7 debe ser actualizado
# ---> Paquete file-devel.x86_64 0:5.11-35.el7 debe ser una actualización
# ---> Paquete file-libs.x86_64 0:5.11-33.el7 debe ser actualizado
# ---> Paquete file-libs.x86_64 0:5.11-35.el7 debe ser una actualización
# ---> Paquete findutils.x86_64 1:4.5.11-5.el7 debe ser actualizado
# ---> Paquete findutils.x86_64 1:4.5.11-6.el7 debe ser una actualización
# ---> Paquete firewalld.noarch 0:0.4.4.4-14.el7 debe ser actualizado
# ---> Paquete firewalld.noarch 0:0.5.3-5.el7 debe ser una actualización
# ---> Paquete firewalld-filesystem.noarch 0:0.4.4.4-14.el7 debe ser actualizado
# ---> Paquete firewalld-filesystem.noarch 0:0.5.3-5.el7 debe ser una actualización
# ---> Paquete flex.x86_64 0:2.5.37-3.el7 debe ser actualizado
# ---> Paquete flex.x86_64 0:2.5.37-6.el7 debe ser una actualización
# ---> Paquete fontconfig.x86_64 0:2.10.95-11.el7 debe ser actualizado
# ---> Paquete fontconfig.x86_64 0:2.13.0-4.3.el7 debe ser una actualización
# --> Procesando dependencias: dejavu-sans-fonts para el paquete: fontconfig-2.13.0-4.3.el7.x86_64
# ---> Paquete fontconfig-devel.x86_64 0:2.10.95-11.el7 debe ser actualizado
# ---> Paquete fontconfig-devel.x86_64 0:2.13.0-4.3.el7 debe ser una actualización
# --> Procesando dependencias: pkgconfig(uuid) para el paquete: fontconfig-devel-2.13.0-4.3.el7.x86_64
# ---> Paquete freetype.x86_64 0:2.4.11-15.el7 debe ser actualizado
# ---> Paquete freetype.x86_64 0:2.8-12.el7_6.1 debe ser una actualización
# ---> Paquete freetype-devel.x86_64 0:2.4.11-15.el7 debe ser actualizado
# ---> Paquete freetype-devel.x86_64 0:2.8-12.el7_6.1 debe ser una actualización
# ---> Paquete gcc.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete gcc.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete gcc-c++.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete gcc-c++.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete gcc-gfortran.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete gcc-gfortran.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete gdb.x86_64 0:7.6.1-110.el7 debe ser actualizado
# ---> Paquete gdb.x86_64 0:7.6.1-114.el7 debe ser una actualización
# ---> Paquete git.x86_64 0:1.8.3.1-14.el7_5 debe ser actualizado
# ---> Paquete git.x86_64 0:1.8.3.1-20.el7 debe ser una actualización
# ---> Paquete glib2.x86_64 0:2.54.2-2.el7 debe ser actualizado
# ---> Paquete glib2.x86_64 0:2.56.1-2.el7 debe ser una actualización
# ---> Paquete glib2-devel.x86_64 0:2.54.2-2.el7 debe ser actualizado
# ---> Paquete glib2-devel.x86_64 0:2.56.1-2.el7 debe ser una actualización
# ---> Paquete glibc.x86_64 0:2.17-222.el7 debe ser actualizado
# ---> Paquete glibc.x86_64 0:2.17-260.el7_6.3 debe ser una actualización
# ---> Paquete glibc-common.x86_64 0:2.17-222.el7 debe ser actualizado
# ---> Paquete glibc-common.x86_64 0:2.17-260.el7_6.3 debe ser una actualización
# ---> Paquete glibc-devel.x86_64 0:2.17-222.el7 debe ser actualizado
# ---> Paquete glibc-devel.x86_64 0:2.17-260.el7_6.3 debe ser una actualización
# ---> Paquete glibc-headers.x86_64 0:2.17-222.el7 debe ser actualizado
# ---> Paquete glibc-headers.x86_64 0:2.17-260.el7_6.3 debe ser una actualización
# ---> Paquete gnupg2.x86_64 0:2.0.22-4.el7 debe ser actualizado
# ---> Paquete gnupg2.x86_64 0:2.0.22-5.el7_5 debe ser una actualización
# ---> Paquete gnutls.x86_64 0:3.3.26-9.el7 debe ser actualizado
# ---> Paquete gnutls.x86_64 0:3.3.29-8.el7 debe ser una actualización
# ---> Paquete gobject-introspection.x86_64 0:1.50.0-1.el7 debe ser actualizado
# ---> Paquete gobject-introspection.x86_64 0:1.56.1-1.el7 debe ser una actualización
# ---> Paquete grub2.x86_64 1:2.02-0.65.el7.centos.2 debe ser obsoleto
# ---> Paquete grub2.x86_64 1:2.02-0.76.el7.centos.1 debe ser obsoleto
# ---> Paquete grub2-common.noarch 1:2.02-0.65.el7.centos.2 debe ser actualizado
# ---> Paquete grub2-common.noarch 1:2.02-0.76.el7.centos.1 debe ser una actualización
# ---> Paquete grub2-pc.x86_64 1:2.02-0.65.el7.centos.2 debe ser actualizado
# ---> Paquete grub2-pc.x86_64 1:2.02-0.76.el7.centos.1 debe ser una actualización
# ---> Paquete grub2-pc-modules.noarch 1:2.02-0.65.el7.centos.2 debe ser actualizado
# ---> Paquete grub2-pc-modules.noarch 1:2.02-0.76.el7.centos.1 debe ser una actualización
# ---> Paquete grub2-tools.x86_64 1:2.02-0.65.el7.centos.2 debe ser obsoleto
# ---> Paquete grub2-tools.x86_64 1:2.02-0.76.el7.centos.1 debe ser obsoleto
# ---> Paquete grub2-tools-extra.x86_64 1:2.02-0.65.el7.centos.2 debe ser actualizado
# ---> Paquete grub2-tools-extra.x86_64 1:2.02-0.76.el7.centos.1 debe ser obsoleto
# ---> Paquete grub2-tools-minimal.x86_64 1:2.02-0.65.el7.centos.2 debe ser actualizado
# ---> Paquete grub2-tools-minimal.x86_64 1:2.02-0.76.el7.centos.1 debe ser obsoleto
# ---> Paquete grubby.x86_64 0:8.28-23.el7 debe ser actualizado
# ---> Paquete grubby.x86_64 0:8.28-25.el7 debe ser una actualización
# ---> Paquete httpd.x86_64 0:2.4.6-80.el7.centos.1 debe ser actualizado
# ---> Paquete httpd.x86_64 0:2.4.6-88.el7.centos debe ser una actualización
# ---> Paquete httpd-tools.x86_64 0:2.4.6-80.el7.centos.1 debe ser actualizado
# ---> Paquete httpd-tools.x86_64 0:2.4.6-88.el7.centos debe ser una actualización
# ---> Paquete hwdata.x86_64 0:0.252-8.8.el7 debe ser actualizado
# ---> Paquete hwdata.x86_64 0:0.252-9.1.el7 debe ser una actualización
# ---> Paquete initscripts.x86_64 0:9.49.41-1.el7 debe ser actualizado
# ---> Paquete initscripts.x86_64 0:9.49.46-1.el7 debe ser una actualización
# ---> Paquete iprutils.x86_64 0:2.4.15.1-1.el7 debe ser actualizado
# ---> Paquete iprutils.x86_64 0:2.4.16.1-1.el7 debe ser una actualización
# ---> Paquete ipset.x86_64 0:6.29-1.el7 debe ser actualizado
# ---> Paquete ipset.x86_64 0:6.38-3.el7_6 debe ser una actualización
# ---> Paquete ipset-libs.x86_64 0:6.29-1.el7 debe ser actualizado
# ---> Paquete ipset-libs.x86_64 0:6.38-3.el7_6 debe ser una actualización
# ---> Paquete iptables.x86_64 0:1.4.21-24.1.el7_5 debe ser actualizado
# ---> Paquete iptables.x86_64 0:1.4.21-28.el7 debe ser una actualización
# ---> Paquete iwl100-firmware.noarch 0:39.31.5.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl100-firmware.noarch 0:39.31.5.1-69.el7 debe ser una actualización
# ---> Paquete iwl1000-firmware.noarch 1:39.31.5.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl1000-firmware.noarch 1:39.31.5.1-69.el7 debe ser una actualización
# ---> Paquete iwl105-firmware.noarch 0:18.168.6.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl105-firmware.noarch 0:18.168.6.1-69.el7 debe ser una actualización
# ---> Paquete iwl135-firmware.noarch 0:18.168.6.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl135-firmware.noarch 0:18.168.6.1-69.el7 debe ser una actualización
# ---> Paquete iwl2000-firmware.noarch 0:18.168.6.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl2000-firmware.noarch 0:18.168.6.1-69.el7 debe ser una actualización
# ---> Paquete iwl2030-firmware.noarch 0:18.168.6.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl2030-firmware.noarch 0:18.168.6.1-69.el7 debe ser una actualización
# ---> Paquete iwl3160-firmware.noarch 0:22.0.7.0-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl3160-firmware.noarch 0:22.0.7.0-69.el7 debe ser una actualización
# ---> Paquete iwl3945-firmware.noarch 0:15.32.2.9-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl3945-firmware.noarch 0:15.32.2.9-69.el7 debe ser una actualización
# ---> Paquete iwl4965-firmware.noarch 0:228.61.2.24-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl4965-firmware.noarch 0:228.61.2.24-69.el7 debe ser una actualización
# ---> Paquete iwl5000-firmware.noarch 0:8.83.5.1_1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl5000-firmware.noarch 0:8.83.5.1_1-69.el7 debe ser una actualización
# ---> Paquete iwl5150-firmware.noarch 0:8.24.2.2-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl5150-firmware.noarch 0:8.24.2.2-69.el7 debe ser una actualización
# ---> Paquete iwl6000-firmware.noarch 0:9.221.4.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl6000-firmware.noarch 0:9.221.4.1-69.el7 debe ser una actualización
# ---> Paquete iwl6000g2a-firmware.noarch 0:17.168.5.3-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl6000g2a-firmware.noarch 0:17.168.5.3-69.el7 debe ser una actualización
# ---> Paquete iwl6000g2b-firmware.noarch 0:17.168.5.2-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl6000g2b-firmware.noarch 0:17.168.5.2-69.el7 debe ser una actualización
# ---> Paquete iwl6050-firmware.noarch 0:41.28.5.1-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl6050-firmware.noarch 0:41.28.5.1-69.el7 debe ser una actualización
# ---> Paquete iwl7260-firmware.noarch 0:22.0.7.0-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl7260-firmware.noarch 0:22.0.7.0-69.el7 debe ser una actualización
# ---> Paquete iwl7265-firmware.noarch 0:22.0.7.0-62.2.el7_5 debe ser actualizado
# ---> Paquete iwl7265-firmware.noarch 0:22.0.7.0-69.el7 debe ser una actualización
# ---> Paquete kbd.x86_64 0:1.15.5-13.el7 debe ser actualizado
# ---> Paquete kbd.x86_64 0:1.15.5-15.el7 debe ser una actualización
# ---> Paquete kbd-legacy.noarch 0:1.15.5-13.el7 debe ser actualizado
# ---> Paquete kbd-legacy.noarch 0:1.15.5-15.el7 debe ser una actualización
# ---> Paquete kbd-misc.noarch 0:1.15.5-13.el7 debe ser actualizado
# ---> Paquete kbd-misc.noarch 0:1.15.5-15.el7 debe ser una actualización
# ---> Paquete kernel.x86_64 0:3.10.0-957.5.1.el7 debe ser instalado
# ---> Paquete kernel-debug-devel.x86_64 0:3.10.0-862.6.3.el7 debe ser actualizado
# ---> Paquete kernel-debug-devel.x86_64 0:3.10.0-957.5.1.el7 debe ser una actualización
# ---> Paquete kernel-headers.x86_64 0:3.10.0-862.6.3.el7 debe ser actualizado
# ---> Paquete kernel-headers.x86_64 0:3.10.0-957.5.1.el7 debe ser una actualización
# ---> Paquete kernel-tools.x86_64 0:3.10.0-862.6.3.el7 debe ser actualizado
# ---> Paquete kernel-tools.x86_64 0:3.10.0-957.5.1.el7 debe ser una actualización
# ---> Paquete kernel-tools-libs.x86_64 0:3.10.0-862.6.3.el7 debe ser actualizado
# ---> Paquete kernel-tools-libs.x86_64 0:3.10.0-957.5.1.el7 debe ser una actualización
# ---> Paquete kexec-tools.x86_64 0:2.0.15-13.el7 debe ser actualizado
# ---> Paquete kexec-tools.x86_64 0:2.0.15-21.el7 debe ser una actualización
# ---> Paquete kmod.x86_64 0:20-21.el7 debe ser actualizado
# ---> Paquete kmod.x86_64 0:20-23.el7 debe ser una actualización
# ---> Paquete kmod-libs.x86_64 0:20-21.el7 debe ser actualizado
# ---> Paquete kmod-libs.x86_64 0:20-23.el7 debe ser una actualización
# ---> Paquete kpartx.x86_64 0:0.4.9-119.el7 debe ser actualizado
# ---> Paquete kpartx.x86_64 0:0.4.9-123.el7 debe ser una actualización
# ---> Paquete krb5-devel.x86_64 0:1.15.1-19.el7 debe ser actualizado
# ---> Paquete krb5-devel.x86_64 0:1.15.1-37.el7_6 debe ser una actualización
# ---> Paquete krb5-libs.x86_64 0:1.15.1-19.el7 debe ser actualizado
# ---> Paquete krb5-libs.x86_64 0:1.15.1-37.el7_6 debe ser una actualización
# ---> Paquete libX11.x86_64 0:1.6.5-1.el7 debe ser actualizado
# ---> Paquete libX11.x86_64 0:1.6.5-2.el7 debe ser una actualización
# ---> Paquete libX11-common.noarch 0:1.6.5-1.el7 debe ser actualizado
# ---> Paquete libX11-common.noarch 0:1.6.5-2.el7 debe ser una actualización
# ---> Paquete libX11-devel.x86_64 0:1.6.5-1.el7 debe ser actualizado
# ---> Paquete libX11-devel.x86_64 0:1.6.5-2.el7 debe ser una actualización
# ---> Paquete libblkid.x86_64 0:2.23.2-52.el7 debe ser actualizado
# ---> Paquete libblkid.x86_64 0:2.23.2-59.el7 debe ser una actualización
# ---> Paquete libcom_err.x86_64 0:1.42.9-12.el7_5 debe ser actualizado
# ---> Paquete libcom_err.x86_64 0:1.42.9-13.el7 debe ser una actualización
# ---> Paquete libcom_err-devel.x86_64 0:1.42.9-12.el7_5 debe ser actualizado
# ---> Paquete libcom_err-devel.x86_64 0:1.42.9-13.el7 debe ser una actualización
# ---> Paquete libcroco.x86_64 0:0.6.11-1.el7 debe ser actualizado
# ---> Paquete libcroco.x86_64 0:0.6.12-4.el7 debe ser una actualización
# ---> Paquete libcurl.x86_64 0:7.29.0-46.el7 debe ser actualizado
# ---> Paquete libcurl.x86_64 0:7.29.0-51.el7 debe ser una actualización
# ---> Paquete libcurl-devel.x86_64 0:7.29.0-46.el7 debe ser actualizado
# ---> Paquete libcurl-devel.x86_64 0:7.29.0-51.el7 debe ser una actualización
# ---> Paquete libdrm.x86_64 0:2.4.83-2.el7 debe ser actualizado
# ---> Paquete libdrm.x86_64 0:2.4.91-3.el7 debe ser una actualización
# ---> Paquete libdrm-devel.x86_64 0:2.4.83-2.el7 debe ser actualizado
# ---> Paquete libdrm-devel.x86_64 0:2.4.91-3.el7 debe ser una actualización
# ---> Paquete libfastjson.x86_64 0:0.99.4-2.el7 debe ser actualizado
# ---> Paquete libfastjson.x86_64 0:0.99.4-3.el7 debe ser una actualización
# ---> Paquete libgcc.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete libgcc.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete libgfortran.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete libgfortran.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete libgomp.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete libgomp.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete libicu.x86_64 0:50.1.2-15.el7 debe ser actualizado
# ---> Paquete libicu.x86_64 0:50.1.2-17.el7 debe ser una actualización
# ---> Paquete libjpeg-turbo.x86_64 0:1.2.90-5.el7 debe ser actualizado
# ---> Paquete libjpeg-turbo.x86_64 0:1.2.90-6.el7 debe ser una actualización
# ---> Paquete libkadm5.x86_64 0:1.15.1-19.el7 debe ser actualizado
# ---> Paquete libkadm5.x86_64 0:1.15.1-37.el7_6 debe ser una actualización
# ---> Paquete libmount.x86_64 0:2.23.2-52.el7 debe ser actualizado
# ---> Paquete libmount.x86_64 0:2.23.2-59.el7 debe ser una actualización
# ---> Paquete libquadmath.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete libquadmath.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete libquadmath-devel.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete libquadmath-devel.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete libselinux.x86_64 0:2.5-12.el7 debe ser actualizado
# ---> Paquete libselinux.x86_64 0:2.5-14.1.el7 debe ser una actualización
# ---> Paquete libselinux-devel.x86_64 0:2.5-12.el7 debe ser actualizado
# ---> Paquete libselinux-devel.x86_64 0:2.5-14.1.el7 debe ser una actualización
# ---> Paquete libselinux-python.x86_64 0:2.5-12.el7 debe ser actualizado
# ---> Paquete libselinux-python.x86_64 0:2.5-14.1.el7 debe ser una actualización
# ---> Paquete libselinux-utils.x86_64 0:2.5-12.el7 debe ser actualizado
# ---> Paquete libselinux-utils.x86_64 0:2.5-14.1.el7 debe ser una actualización
# ---> Paquete libsemanage.x86_64 0:2.5-11.el7 debe ser actualizado
# ---> Paquete libsemanage.x86_64 0:2.5-14.el7 debe ser una actualización
# ---> Paquete libsepol.x86_64 0:2.5-8.1.el7 debe ser actualizado
# ---> Paquete libsepol.x86_64 0:2.5-10.el7 debe ser una actualización
# ---> Paquete libsepol-devel.x86_64 0:2.5-8.1.el7 debe ser actualizado
# ---> Paquete libsepol-devel.x86_64 0:2.5-10.el7 debe ser una actualización
# ---> Paquete libss.x86_64 0:1.42.9-12.el7_5 debe ser actualizado
# ---> Paquete libss.x86_64 0:1.42.9-13.el7 debe ser una actualización
# ---> Paquete libssh2.x86_64 0:1.4.3-10.el7_2.1 debe ser actualizado
# ---> Paquete libssh2.x86_64 0:1.4.3-12.el7 debe ser una actualización
# ---> Paquete libstdc++.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete libstdc++.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete libstdc++-devel.x86_64 0:4.8.5-28.el7_5.1 debe ser actualizado
# ---> Paquete libstdc++-devel.x86_64 0:4.8.5-36.el7 debe ser una actualización
# ---> Paquete libteam.x86_64 0:1.27-4.el7 debe ser actualizado
# ---> Paquete libteam.x86_64 0:1.27-5.el7 debe ser una actualización
# ---> Paquete libuuid.x86_64 0:2.23.2-52.el7 debe ser actualizado
# ---> Paquete libuuid.x86_64 0:2.23.2-59.el7 debe ser una actualización
# ---> Paquete libuv.x86_64 1:1.19.2-1.el7 debe ser actualizado
# ---> Paquete libuv.x86_64 1:1.26.0-1.el7 debe ser una actualización
# ---> Paquete libwayland-client.x86_64 0:1.14.0-2.el7 debe ser actualizado
# ---> Paquete libwayland-client.x86_64 0:1.15.0-1.el7 debe ser una actualización
# ---> Paquete libwayland-server.x86_64 0:1.14.0-2.el7 debe ser actualizado
# ---> Paquete libwayland-server.x86_64 0:1.15.0-1.el7 debe ser una actualización
# ---> Paquete libxcb.x86_64 0:1.12-1.el7 debe ser actualizado
# ---> Paquete libxcb.x86_64 0:1.13-1.el7 debe ser una actualización
# ---> Paquete libxcb-devel.x86_64 0:1.12-1.el7 debe ser actualizado
# ---> Paquete libxcb-devel.x86_64 0:1.13-1.el7 debe ser una actualización
# ---> Paquete linux-firmware.noarch 0:20180220-62.2.git6d51311.el7_5 debe ser actualizado
# ---> Paquete linux-firmware.noarch 0:20180911-69.git85c5d90.el7 debe ser una actualización
# ---> Paquete logrotate.x86_64 0:3.8.6-15.el7 debe ser actualizado
# ---> Paquete logrotate.x86_64 0:3.8.6-17.el7 debe ser una actualización
# ---> Paquete lvm2.x86_64 7:2.02.177-4.el7 debe ser actualizado
# ---> Paquete lvm2.x86_64 7:2.02.180-10.el7_6.3 debe ser una actualización
# ---> Paquete lvm2-libs.x86_64 7:2.02.177-4.el7 debe ser actualizado
# ---> Paquete lvm2-libs.x86_64 7:2.02.180-10.el7_6.3 debe ser una actualización
# ---> Paquete man-db.x86_64 0:2.6.3-9.el7 debe ser actualizado
# ---> Paquete man-db.x86_64 0:2.6.3-11.el7 debe ser una actualización
# ---> Paquete mariadb.x86_64 1:5.5.56-2.el7 debe ser actualizado
# ---> Paquete mariadb.x86_64 1:5.5.60-1.el7_5 debe ser una actualización
# ---> Paquete mariadb-libs.x86_64 1:5.5.56-2.el7 debe ser actualizado
# ---> Paquete mariadb-libs.x86_64 1:5.5.60-1.el7_5 debe ser una actualización
# ---> Paquete mariadb-server.x86_64 1:5.5.56-2.el7 debe ser actualizado
# ---> Paquete mariadb-server.x86_64 1:5.5.60-1.el7_5 debe ser una actualización
# ---> Paquete mesa-libEGL.x86_64 0:17.2.3-8.20171019.el7 debe ser actualizado
# ---> Paquete mesa-libEGL.x86_64 0:18.0.5-4.el7_6 debe ser una actualización
# ---> Paquete mesa-libEGL-devel.x86_64 0:17.2.3-8.20171019.el7 debe ser actualizado
# ---> Paquete mesa-libEGL-devel.x86_64 0:18.0.5-4.el7_6 debe ser una actualización
# --> Procesando dependencias: libglvnd-devel(x86-64) para el paquete: mesa-libEGL-devel-18.0.5-4.el7_6.x86_64
# ---> Paquete mesa-libGL.x86_64 0:17.2.3-8.20171019.el7 debe ser actualizado
# ---> Paquete mesa-libGL.x86_64 0:18.0.5-4.el7_6 debe ser una actualización
# ---> Paquete mesa-libGL-devel.x86_64 0:17.2.3-8.20171019.el7 debe ser actualizado
# ---> Paquete mesa-libGL-devel.x86_64 0:18.0.5-4.el7_6 debe ser una actualización
# ---> Paquete mesa-libgbm.x86_64 0:17.2.3-8.20171019.el7 debe ser actualizado
# ---> Paquete mesa-libgbm.x86_64 0:18.0.5-4.el7_6 debe ser una actualización
# ---> Paquete mesa-libglapi.x86_64 0:17.2.3-8.20171019.el7 debe ser actualizado
# ---> Paquete mesa-libglapi.x86_64 0:18.0.5-4.el7_6 debe ser una actualización
# ---> Paquete microcode_ctl.x86_64 2:2.1-29.2.el7_5 debe ser actualizado
# ---> Paquete microcode_ctl.x86_64 2:2.1-47.el7 debe ser una actualización
# ---> Paquete mokutil.x86_64 0:12-1.el7.centos debe ser actualizado
# ---> Paquete mokutil.x86_64 0:15-2.el7.centos debe ser una actualización
# ---> Paquete nodejs.x86_64 1:6.14.3-1.el7 debe ser actualizado
# ---> Paquete nodejs.x86_64 1:6.16.0-1.el7 debe ser una actualización
# ---> Paquete npm.x86_64 1:3.10.10-1.6.14.3.1.el7 debe ser actualizado
# ---> Paquete npm.x86_64 1:3.10.10-1.6.16.0.1.el7 debe ser una actualización
# ---> Paquete nss.x86_64 0:3.36.0-5.el7_5 debe ser actualizado
# ---> Paquete nss.x86_64 0:3.36.0-7.1.el7_6 debe ser una actualización
# ---> Paquete nss-pem.x86_64 0:1.0.3-4.el7 debe ser actualizado
# ---> Paquete nss-pem.x86_64 0:1.0.3-5.el7 debe ser una actualización
# ---> Paquete nss-sysinit.x86_64 0:3.36.0-5.el7_5 debe ser actualizado
# ---> Paquete nss-sysinit.x86_64 0:3.36.0-7.1.el7_6 debe ser una actualización
# ---> Paquete nss-tools.x86_64 0:3.36.0-5.el7_5 debe ser actualizado
# ---> Paquete nss-tools.x86_64 0:3.36.0-7.1.el7_6 debe ser una actualización
# ---> Paquete nss-util.x86_64 0:3.36.0-1.el7_5 debe ser actualizado
# ---> Paquete nss-util.x86_64 0:3.36.0-1.1.el7_6 debe ser una actualización
# ---> Paquete openldap.x86_64 0:2.4.44-15.el7_5 debe ser actualizado
# ---> Paquete openldap.x86_64 0:2.4.44-21.el7_6 debe ser una actualización
# ---> Paquete openssl.x86_64 1:1.0.2k-12.el7 debe ser actualizado
# ---> Paquete openssl.x86_64 1:1.0.2k-16.el7 debe ser una actualización
# ---> Paquete openssl-devel.x86_64 1:1.0.2k-12.el7 debe ser actualizado
# ---> Paquete openssl-devel.x86_64 1:1.0.2k-16.el7 debe ser una actualización
# ---> Paquete openssl-libs.x86_64 1:1.0.2k-12.el7 debe ser actualizado
# ---> Paquete openssl-libs.x86_64 1:1.0.2k-16.el7 debe ser una actualización
# ---> Paquete perl.x86_64 4:5.16.3-292.el7 debe ser actualizado
# ---> Paquete perl.x86_64 4:5.16.3-294.el7_6 debe ser una actualización
# ---> Paquete perl-Git.noarch 0:1.8.3.1-14.el7_5 debe ser actualizado
# ---> Paquete perl-Git.noarch 0:1.8.3.1-20.el7 debe ser una actualización
# ---> Paquete perl-Pod-Escapes.noarch 1:1.04-292.el7 debe ser actualizado
# ---> Paquete perl-Pod-Escapes.noarch 1:1.04-294.el7_6 debe ser una actualización
# ---> Paquete perl-libs.x86_64 4:5.16.3-292.el7 debe ser actualizado
# ---> Paquete perl-libs.x86_64 4:5.16.3-294.el7_6 debe ser una actualización
# ---> Paquete perl-macros.x86_64 4:5.16.3-292.el7 debe ser actualizado
# ---> Paquete perl-macros.x86_64 4:5.16.3-294.el7_6 debe ser una actualización
# ---> Paquete php.x86_64 0:5.4.16-45.el7 debe ser actualizado
# ---> Paquete php.x86_64 0:5.4.16-46.el7 debe ser una actualización
# ---> Paquete php-cli.x86_64 0:5.4.16-45.el7 debe ser actualizado
# ---> Paquete php-cli.x86_64 0:5.4.16-46.el7 debe ser una actualización
# ---> Paquete php-common.x86_64 0:5.4.16-45.el7 debe ser actualizado
# ---> Paquete php-common.x86_64 0:5.4.16-46.el7 debe ser una actualización
# ---> Paquete php-gd.x86_64 0:5.4.16-45.el7 debe ser actualizado
# ---> Paquete php-gd.x86_64 0:5.4.16-46.el7 debe ser una actualización
# ---> Paquete php-ldap.x86_64 0:5.4.16-45.el7 debe ser actualizado
# ---> Paquete php-ldap.x86_64 0:5.4.16-46.el7 debe ser una actualización
# ---> Paquete php-mysql.x86_64 0:5.4.16-45.el7 debe ser actualizado
# ---> Paquete php-mysql.x86_64 0:5.4.16-46.el7 debe ser una actualización
# ---> Paquete php-pdo.x86_64 0:5.4.16-45.el7 debe ser actualizado
# ---> Paquete php-pdo.x86_64 0:5.4.16-46.el7 debe ser una actualización
# ---> Paquete policycoreutils.x86_64 0:2.5-22.el7 debe ser actualizado
# ---> Paquete policycoreutils.x86_64 0:2.5-29.el7_6.1 debe ser una actualización
# ---> Paquete polkit.x86_64 0:0.112-14.el7 debe ser actualizado
# ---> Paquete polkit.x86_64 0:0.112-18.el7_6.1 debe ser una actualización
# ---> Paquete postfix.x86_64 2:2.10.1-6.el7 debe ser actualizado
# ---> Paquete postfix.x86_64 2:2.10.1-7.el7 debe ser una actualización
# ---> Paquete procps-ng.x86_64 0:3.3.10-17.el7_5.2 debe ser actualizado
# ---> Paquete procps-ng.x86_64 0:3.3.10-23.el7 debe ser una actualización
# ---> Paquete python.x86_64 0:2.7.5-68.el7 debe ser actualizado
# ---> Paquete python.x86_64 0:2.7.5-76.el7 debe ser una actualización
# ---> Paquete python-firewall.noarch 0:0.4.4.4-14.el7 debe ser actualizado
# ---> Paquete python-firewall.noarch 0:0.5.3-5.el7 debe ser una actualización
# ---> Paquete python-libs.x86_64 0:2.7.5-68.el7 debe ser actualizado
# ---> Paquete python-libs.x86_64 0:2.7.5-76.el7 debe ser una actualización
# ---> Paquete python-linux-procfs.noarch 0:0.4.9-3.el7 debe ser actualizado
# ---> Paquete python-linux-procfs.noarch 0:0.4.9-4.el7 debe ser una actualización
# ---> Paquete python-perf.x86_64 0:3.10.0-862.6.3.el7 debe ser actualizado
# ---> Paquete python-perf.x86_64 0:3.10.0-957.5.1.el7 debe ser una actualización
# ---> Paquete python-rpm-macros.noarch 0:3-18.el7 debe ser actualizado
# ---> Paquete python-rpm-macros.noarch 0:3-22.el7 debe ser una actualización
# ---> Paquete python-srpm-macros.noarch 0:3-18.el7 debe ser actualizado
# ---> Paquete python-srpm-macros.noarch 0:3-22.el7 debe ser una actualización
# ---> Paquete python-urlgrabber.noarch 0:3.10-8.el7 debe ser actualizado
# ---> Paquete python-urlgrabber.noarch 0:3.10-9.el7 debe ser una actualización
# ---> Paquete python36.x86_64 0:3.6.3-7.el7 debe ser actualizado
# ---> Paquete python36.x86_64 0:3.6.6-2.el7 debe ser una actualización
# ---> Paquete python36-devel.x86_64 0:3.6.3-7.el7 debe ser actualizado
# ---> Paquete python36-devel.x86_64 0:3.6.6-2.el7 debe ser una actualización
# --> Procesando dependencias: python3-rpm-macros para el paquete: python36-devel-3.6.6-2.el7.x86_64
# ---> Paquete python36-libs.x86_64 0:3.6.3-7.el7 debe ser actualizado
# ---> Paquete python36-libs.x86_64 0:3.6.6-2.el7 debe ser una actualización
# ---> Paquete redhat-rpm-config.noarch 0:9.1.0-80.el7.centos debe ser actualizado
# ---> Paquete redhat-rpm-config.noarch 0:9.1.0-87.el7.centos debe ser una actualización
# ---> Paquete rpm.x86_64 0:4.11.3-32.el7 debe ser actualizado
# ---> Paquete rpm.x86_64 0:4.11.3-35.el7 debe ser una actualización
# ---> Paquete rpm-build.x86_64 0:4.11.3-32.el7 debe ser actualizado
# ---> Paquete rpm-build.x86_64 0:4.11.3-35.el7 debe ser una actualización
# ---> Paquete rpm-build-libs.x86_64 0:4.11.3-32.el7 debe ser actualizado
# ---> Paquete rpm-build-libs.x86_64 0:4.11.3-35.el7 debe ser una actualización
# ---> Paquete rpm-libs.x86_64 0:4.11.3-32.el7 debe ser actualizado
# ---> Paquete rpm-libs.x86_64 0:4.11.3-35.el7 debe ser una actualización
# ---> Paquete rpm-python.x86_64 0:4.11.3-32.el7 debe ser actualizado
# ---> Paquete rpm-python.x86_64 0:4.11.3-35.el7 debe ser una actualización
# ---> Paquete rpm-sign.x86_64 0:4.11.3-32.el7 debe ser actualizado
# ---> Paquete rpm-sign.x86_64 0:4.11.3-35.el7 debe ser una actualización
# ---> Paquete rsyslog.x86_64 0:8.24.0-16.el7_5.4 debe ser actualizado
# ---> Paquete rsyslog.x86_64 0:8.24.0-34.el7 debe ser una actualización
# ---> Paquete selinux-policy.noarch 0:3.13.1-192.el7_5.4 debe ser actualizado
# ---> Paquete selinux-policy.noarch 0:3.13.1-229.el7_6.9 debe ser una actualización
# ---> Paquete selinux-policy-targeted.noarch 0:3.13.1-192.el7_5.4 debe ser actualizado
# ---> Paquete selinux-policy-targeted.noarch 0:3.13.1-229.el7_6.9 debe ser una actualización
# ---> Paquete setup.noarch 0:2.8.71-9.el7 debe ser actualizado
# ---> Paquete setup.noarch 0:2.8.71-10.el7 debe ser una actualización
# ---> Paquete shadow-utils.x86_64 2:4.1.5.1-24.el7 debe ser actualizado
# ---> Paquete shadow-utils.x86_64 2:4.1.5.1-25.el7 debe ser una actualización
# ---> Paquete sudo.x86_64 0:1.8.19p2-14.el7_5 debe ser actualizado
# ---> Paquete sudo.x86_64 0:1.8.23-3.el7 debe ser una actualización
# ---> Paquete systemd.x86_64 0:219-57.el7 debe ser actualizado
# ---> Paquete systemd.x86_64 0:219-62.el7_6.5 debe ser una actualización
# ---> Paquete systemd-libs.x86_64 0:219-57.el7 debe ser actualizado
# ---> Paquete systemd-libs.x86_64 0:219-62.el7_6.5 debe ser una actualización
# ---> Paquete systemd-sysv.x86_64 0:219-57.el7 debe ser actualizado
# ---> Paquete systemd-sysv.x86_64 0:219-62.el7_6.5 debe ser una actualización
# ---> Paquete systemtap.x86_64 0:3.2-8.el7_5 debe ser actualizado
# ---> Paquete systemtap.x86_64 0:3.3-3.el7 debe ser una actualización
# ---> Paquete systemtap-client.x86_64 0:3.2-8.el7_5 debe ser actualizado
# ---> Paquete systemtap-client.x86_64 0:3.3-3.el7 debe ser una actualización
# ---> Paquete systemtap-devel.x86_64 0:3.2-8.el7_5 debe ser actualizado
# ---> Paquete systemtap-devel.x86_64 0:3.3-3.el7 debe ser una actualización
# ---> Paquete systemtap-runtime.x86_64 0:3.2-8.el7_5 debe ser actualizado
# ---> Paquete systemtap-runtime.x86_64 0:3.3-3.el7 debe ser una actualización
# ---> Paquete tar.x86_64 2:1.26-34.el7 debe ser actualizado
# ---> Paquete tar.x86_64 2:1.26-35.el7 debe ser una actualización
# ---> Paquete teamd.x86_64 0:1.27-4.el7 debe ser actualizado
# ---> Paquete teamd.x86_64 0:1.27-5.el7 debe ser una actualización
# ---> Paquete tuned.noarch 0:2.9.0-1.el7 debe ser actualizado
# ---> Paquete tuned.noarch 0:2.10.0-6.el7 debe ser una actualización
# ---> Paquete tzdata.noarch 0:2018e-3.el7 debe ser actualizado
# ---> Paquete tzdata.noarch 0:2018i-1.el7 debe ser una actualización
# ---> Paquete util-linux.x86_64 0:2.23.2-52.el7 debe ser actualizado
# ---> Paquete util-linux.x86_64 0:2.23.2-59.el7 debe ser una actualización
# --> Procesando dependencias: libsmartcols = 2.23.2-59.el7 para el paquete: util-linux-2.23.2-59.el7.x86_64
# --> Procesando dependencias: libsmartcols.so.1(SMARTCOLS_2.25)(64bit) para el paquete: util-linux-2.23.2-59.el7.x86_64
# --> Procesando dependencias: libsmartcols.so.1()(64bit) para el paquete: util-linux-2.23.2-59.el7.x86_64
# ---> Paquete vim-minimal.x86_64 2:7.4.160-4.el7 debe ser actualizado
# ---> Paquete vim-minimal.x86_64 2:7.4.160-5.el7 debe ser una actualización
# ---> Paquete wget.x86_64 0:1.14-15.el7_4.1 debe ser actualizado
# ---> Paquete wget.x86_64 0:1.14-18.el7 debe ser una actualización
# ---> Paquete wpa_supplicant.x86_64 1:2.6-9.el7 debe ser actualizado
# ---> Paquete wpa_supplicant.x86_64 1:2.6-12.el7 debe ser una actualización
# ---> Paquete xfsprogs.x86_64 0:4.5.0-15.el7 debe ser actualizado
# ---> Paquete xfsprogs.x86_64 0:4.5.0-18.el7 debe ser una actualización
# ---> Paquete xorg-x11-proto-devel.noarch 0:7.7-20.el7 debe ser actualizado
# ---> Paquete xorg-x11-proto-devel.noarch 0:2018.4-1.el7 debe ser una actualización
# ---> Paquete yum.noarch 0:3.4.3-158.el7.centos debe ser actualizado
# ---> Paquete yum.noarch 0:3.4.3-161.el7.centos debe ser una actualización
# ---> Paquete yum-plugin-fastestmirror.noarch 0:1.1.31-45.el7 debe ser actualizado
# ---> Paquete yum-plugin-fastestmirror.noarch 0:1.1.31-50.el7 debe ser una actualización
# ---> Paquete yum-utils.noarch 0:1.1.31-45.el7 debe ser actualizado
# ---> Paquete yum-utils.noarch 0:1.1.31-50.el7 debe ser una actualización
# ---> Paquete zeromq.x86_64 0:4.1.4-5.el7 debe ser actualizado
# ---> Paquete zeromq.x86_64 0:4.1.4-6.el7 debe ser una actualización
# --> Procesando dependencias: libsodium.so.23()(64bit) para el paquete: zeromq-4.1.4-6.el7.x86_64
# ---> Paquete zeromq-devel.x86_64 0:4.1.4-5.el7 debe ser actualizado
# ---> Paquete zeromq-devel.x86_64 0:4.1.4-6.el7 debe ser una actualización
# ---> Paquete zlib.x86_64 0:1.2.7-17.el7 debe ser actualizado
# ---> Paquete zlib.x86_64 0:1.2.7-18.el7 debe ser una actualización
# ---> Paquete zlib-devel.x86_64 0:1.2.7-17.el7 debe ser actualizado
# ---> Paquete zlib-devel.x86_64 0:1.2.7-18.el7 debe ser una actualización
# --> Ejecutando prueba de transacción
# ---> Paquete dejavu-sans-fonts.noarch 0:2.33-6.el7 debe ser instalado
# --> Procesando dependencias: dejavu-fonts-common = 2.33-6.el7 para el paquete: dejavu-sans-fonts-2.33-6.el7.noarch
# ---> Paquete json-c.x86_64 0:0.11-4.el7_0 debe ser instalado
# ---> Paquete libglvnd-devel.x86_64 1:1.0.1-0.8.git5baa1e5.el7 debe ser instalado
# --> Procesando dependencias: libglvnd-opengl(x86-64) = 1:1.0.1-0.8.git5baa1e5.el7 para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# --> Procesando dependencias: libglvnd-gles(x86-64) = 1:1.0.1-0.8.git5baa1e5.el7 para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# --> Procesando dependencias: libglvnd-core-devel(x86-64) = 1:1.0.1-0.8.git5baa1e5.el7 para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# --> Procesando dependencias: libglvnd(x86-64) = 1:1.0.1-0.8.git5baa1e5.el7 para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# --> Procesando dependencias: libOpenGL.so.0()(64bit) para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# --> Procesando dependencias: libGLdispatch.so.0()(64bit) para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# --> Procesando dependencias: libGLESv2.so.2()(64bit) para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# --> Procesando dependencias: libGLESv1_CM.so.1()(64bit) para el paquete: 1:libglvnd-devel-1.0.1-0.8.git5baa1e5.el7.x86_64
# ---> Paquete libglvnd-egl.x86_64 1:1.0.1-0.8.git5baa1e5.el7 debe ser instalado
# ---> Paquete libglvnd-glx.x86_64 1:1.0.1-0.8.git5baa1e5.el7 debe ser instalado
# ---> Paquete libsmartcols.x86_64 0:2.23.2-59.el7 debe ser instalado
# ---> Paquete libsodium.x86_64 0:1.0.17-1.el7 debe ser instalado
# ---> Paquete libuuid-devel.x86_64 0:2.23.2-59.el7 debe ser instalado
# ---> Paquete python3-rpm-macros.noarch 0:3-22.el7 debe ser instalado
# --> Ejecutando prueba de transacción
# ---> Paquete dejavu-fonts-common.noarch 0:2.33-6.el7 debe ser instalado
# ---> Paquete libglvnd.x86_64 1:1.0.1-0.8.git5baa1e5.el7 debe ser instalado
# ---> Paquete libglvnd-core-devel.x86_64 1:1.0.1-0.8.git5baa1e5.el7 debe ser instalado
# ---> Paquete libglvnd-gles.x86_64 1:1.0.1-0.8.git5baa1e5.el7 debe ser instalado
# ---> Paquete libglvnd-opengl.x86_64 1:1.0.1-0.8.git5baa1e5.el7 debe ser instalado
# --> Resolución de dependencias finalizada
#
# Dependencias resueltas
#
# ================================================================================
#  Package                     Arquitectura
#                                     Versión                       Repositorio
#                                                                           Tamaño
# ================================================================================
# Instalando:
#  grub2                       x86_64 1:2.02-0.76.el7.centos.1      updates  31 k
#      reemplazando  grub2.x86_64 1:2.02-0.65.el7.centos.2
#  grub2-tools                 x86_64 1:2.02-0.76.el7.centos.1      updates 1.8 M
#      reemplazando  grub2-tools.x86_64 1:2.02-0.65.el7.centos.2
#  grub2-tools-extra           x86_64 1:2.02-0.76.el7.centos.1      updates 995 k
#      reemplazando  grub2-tools.x86_64 1:2.02-0.65.el7.centos.2
#  grub2-tools-minimal         x86_64 1:2.02-0.76.el7.centos.1      updates 172 k
#      reemplazando  grub2-tools.x86_64 1:2.02-0.65.el7.centos.2
#  kernel                      x86_64 3.10.0-957.5.1.el7            updates  48 M
# Actualizando:
#  GeoIP                       x86_64 1.5.0-13.el7                  base    1.5 M
#  NetworkManager              x86_64 1:1.12.0-8.el7_6              updates 1.7 M
#  NetworkManager-libnm        x86_64 1:1.12.0-8.el7_6              updates 1.4 M
#  NetworkManager-team         x86_64 1:1.12.0-8.el7_6              updates 159 k
#  NetworkManager-tui          x86_64 1:1.12.0-8.el7_6              updates 239 k
#  NetworkManager-wifi         x86_64 1:1.12.0-8.el7_6              updates 187 k
#  alsa-lib                    x86_64 1.1.6-2.el7                   base    424 k
#  audit                       x86_64 2.8.4-4.el7                   base    250 k
#  audit-libs                  x86_64 2.8.4-4.el7                   base    100 k
#  bash                        x86_64 4.2.46-31.el7                 base    1.0 M
#  bind-libs-lite              x86_64 32:9.9.4-73.el7_6             updates 741 k
#  bind-license                noarch 32:9.9.4-73.el7_6             updates  87 k
#  binutils                    x86_64 2.27-34.base.el7              base    5.9 M
#  bison                       x86_64 3.0.4-2.el7                   base    674 k
#  cairo                       x86_64 1.15.12-3.el7                 base    741 k
#  cairo-devel                 x86_64 1.15.12-3.el7                 base    267 k
#  centos-release              x86_64 7-6.1810.2.el7.centos         base     26 k
#  coreutils                   x86_64 8.22-23.el7                   base    3.3 M
#  cpp                         x86_64 4.8.5-36.el7                  base    5.9 M
#  cronie                      x86_64 1.4.11-20.el7_6               updates  91 k
#  cronie-anacron              x86_64 1.4.11-20.el7_6               updates  36 k
#  cryptsetup-libs             x86_64 2.0.3-3.el7                   base    338 k
#  curl                        x86_64 7.29.0-51.el7                 base    269 k
#  dbus                        x86_64 1:1.10.24-12.el7              base    245 k
#  dbus-libs                   x86_64 1:1.10.24-12.el7              base    169 k
#  device-mapper               x86_64 7:1.02.149-10.el7_6.3         updates 292 k
#  device-mapper-event         x86_64 7:1.02.149-10.el7_6.3         updates 188 k
#  device-mapper-event-libs    x86_64 7:1.02.149-10.el7_6.3         updates 188 k
#  device-mapper-libs          x86_64 7:1.02.149-10.el7_6.3         updates 320 k
#  dmidecode                   x86_64 1:3.1-2.el7                   base     78 k
#  dracut                      x86_64 033-554.el7                   base    327 k
#  dracut-config-rescue        x86_64 033-554.el7                   base     59 k
#  dracut-network              x86_64 033-554.el7                   base    102 k
#  dyninst                     x86_64 9.3.1-2.el7                   base    3.5 M
#  e2fsprogs                   x86_64 1.42.9-13.el7                 base    699 k
#  e2fsprogs-libs              x86_64 1.42.9-13.el7                 base    167 k
#  efivar-libs                 x86_64 36-11.el7_6.1                 updates  89 k
#  elfutils                    x86_64 0.172-2.el7                   base    299 k
#  elfutils-default-yama-scope noarch 0.172-2.el7                   base     32 k
#  elfutils-libelf             x86_64 0.172-2.el7                   base    194 k
#  elfutils-libs               x86_64 0.172-2.el7                   base    285 k
#  emacs-filesystem            noarch 1:24.3-22.el7                 base     58 k
#  ethtool                     x86_64 2:4.8-9.el7                   base    127 k
#  file                        x86_64 5.11-35.el7                   base     57 k
#  file-devel                  x86_64 5.11-35.el7                   base     32 k
#  file-libs                   x86_64 5.11-35.el7                   base    340 k
#  findutils                   x86_64 1:4.5.11-6.el7                base    559 k
#  firewalld                   noarch 0.5.3-5.el7                   base    431 k
#  firewalld-filesystem        noarch 0.5.3-5.el7                   base     49 k
#  flex                        x86_64 2.5.37-6.el7                  base    293 k
#  fontconfig                  x86_64 2.13.0-4.3.el7                base    254 k
#  fontconfig-devel            x86_64 2.13.0-4.3.el7                base    138 k
#  freetype                    x86_64 2.8-12.el7_6.1                updates 380 k
#  freetype-devel              x86_64 2.8-12.el7_6.1                updates 447 k
#  gcc                         x86_64 4.8.5-36.el7                  base     16 M
#  gcc-c++                     x86_64 4.8.5-36.el7                  base    7.2 M
#  gcc-gfortran                x86_64 4.8.5-36.el7                  base    6.7 M
#  gdb                         x86_64 7.6.1-114.el7                 base    2.4 M
#  git                         x86_64 1.8.3.1-20.el7                updates 4.4 M
#  glib2                       x86_64 2.56.1-2.el7                  base    2.5 M
#  glib2-devel                 x86_64 2.56.1-2.el7                  base    453 k
#  glibc                       x86_64 2.17-260.el7_6.3              updates 3.7 M
#  glibc-common                x86_64 2.17-260.el7_6.3              updates  12 M
#  glibc-devel                 x86_64 2.17-260.el7_6.3              updates 1.1 M
#  glibc-headers               x86_64 2.17-260.el7_6.3              updates 683 k
#  gnupg2                      x86_64 2.0.22-5.el7_5                base    1.5 M
#  gnutls                      x86_64 3.3.29-8.el7                  base    680 k
#  gobject-introspection       x86_64 1.56.1-1.el7                  base    241 k
#  grub2-common                noarch 1:2.02-0.76.el7.centos.1      updates 728 k
#  grub2-pc                    x86_64 1:2.02-0.76.el7.centos.1      updates  31 k
#  grub2-pc-modules            noarch 1:2.02-0.76.el7.centos.1      updates 846 k
#  grubby                      x86_64 8.28-25.el7                   base     70 k
#  httpd                       x86_64 2.4.6-88.el7.centos           base    2.7 M
#  httpd-tools                 x86_64 2.4.6-88.el7.centos           base     90 k
#  hwdata                      x86_64 0.252-9.1.el7                 base    2.3 M
#  initscripts                 x86_64 9.49.46-1.el7                 base    439 k
#  iprutils                    x86_64 2.4.16.1-1.el7                base    243 k
#  ipset                       x86_64 6.38-3.el7_6                  updates  43 k
#  ipset-libs                  x86_64 6.38-3.el7_6                  updates  50 k
#  iptables                    x86_64 1.4.21-28.el7                 base    433 k
#  iwl100-firmware             noarch 39.31.5.1-69.el7              base    157 k
#  iwl1000-firmware            noarch 1:39.31.5.1-69.el7            base    220 k
#  iwl105-firmware             noarch 18.168.6.1-69.el7             base    241 k
#  iwl135-firmware             noarch 18.168.6.1-69.el7             base    250 k
#  iwl2000-firmware            noarch 18.168.6.1-69.el7             base    243 k
#  iwl2030-firmware            noarch 18.168.6.1-69.el7             base    252 k
#  iwl3160-firmware            noarch 22.0.7.0-69.el7               base    1.7 M
#  iwl3945-firmware            noarch 15.32.2.9-69.el7              base     95 k
#  iwl4965-firmware            noarch 228.61.2.24-69.el7            base    108 k
#  iwl5000-firmware            noarch 8.83.5.1_1-69.el7             base    301 k
#  iwl5150-firmware            noarch 8.24.2.2-69.el7               base    153 k
#  iwl6000-firmware            noarch 9.221.4.1-69.el7              base    173 k
#  iwl6000g2a-firmware         noarch 17.168.5.3-69.el7             base    316 k
#  iwl6000g2b-firmware         noarch 17.168.5.2-69.el7             base    317 k
#  iwl6050-firmware            noarch 41.28.5.1-69.el7              base    249 k
#  iwl7260-firmware            noarch 22.0.7.0-69.el7               base    1.1 M
#  iwl7265-firmware            noarch 22.0.7.0-69.el7               base    6.4 M
# ...
#   file-devel.x86_64 0:5.11-35.el7
#   file-libs.x86_64 0:5.11-35.el7
#   findutils.x86_64 1:4.5.11-6.el7
#   firewalld.noarch 0:0.5.3-5.el7
#   firewalld-filesystem.noarch 0:0.5.3-5.el7
#   flex.x86_64 0:2.5.37-6.el7
#   fontconfig.x86_64 0:2.13.0-4.3.el7
#   fontconfig-devel.x86_64 0:2.13.0-4.3.el7
#   freetype.x86_64 0:2.8-12.el7_6.1
#   freetype-devel.x86_64 0:2.8-12.el7_6.1
#   gcc.x86_64 0:4.8.5-36.el7
#   gcc-c++.x86_64 0:4.8.5-36.el7
#   gcc-gfortran.x86_64 0:4.8.5-36.el7
#   gdb.x86_64 0:7.6.1-114.el7
#   git.x86_64 0:1.8.3.1-20.el7
#   glib2.x86_64 0:2.56.1-2.el7
#   glib2-devel.x86_64 0:2.56.1-2.el7
#   glibc.x86_64 0:2.17-260.el7_6.3
#   glibc-common.x86_64 0:2.17-260.el7_6.3
#   glibc-devel.x86_64 0:2.17-260.el7_6.3
#   glibc-headers.x86_64 0:2.17-260.el7_6.3
#   gnupg2.x86_64 0:2.0.22-5.el7_5
#   gnutls.x86_64 0:3.3.29-8.el7
#   gobject-introspection.x86_64 0:1.56.1-1.el7
#   grub2-common.noarch 1:2.02-0.76.el7.centos.1
#   grub2-pc.x86_64 1:2.02-0.76.el7.centos.1
#   grub2-pc-modules.noarch 1:2.02-0.76.el7.centos.1
#   grubby.x86_64 0:8.28-25.el7
#   httpd.x86_64 0:2.4.6-88.el7.centos
#   httpd-tools.x86_64 0:2.4.6-88.el7.centos
#   hwdata.x86_64 0:0.252-9.1.el7
#   initscripts.x86_64 0:9.49.46-1.el7
#   iprutils.x86_64 0:2.4.16.1-1.el7
#   ipset.x86_64 0:6.38-3.el7_6
#   ipset-libs.x86_64 0:6.38-3.el7_6
#   iptables.x86_64 0:1.4.21-28.el7
#   iwl100-firmware.noarch 0:39.31.5.1-69.el7
#   iwl1000-firmware.noarch 1:39.31.5.1-69.el7
#   iwl105-firmware.noarch 0:18.168.6.1-69.el7
#   iwl135-firmware.noarch 0:18.168.6.1-69.el7
#   iwl2000-firmware.noarch 0:18.168.6.1-69.el7
#   iwl2030-firmware.noarch 0:18.168.6.1-69.el7
#   iwl3160-firmware.noarch 0:22.0.7.0-69.el7
#   iwl3945-firmware.noarch 0:15.32.2.9-69.el7
#   iwl4965-firmware.noarch 0:228.61.2.24-69.el7
#   iwl5000-firmware.noarch 0:8.83.5.1_1-69.el7
#   iwl5150-firmware.noarch 0:8.24.2.2-69.el7
#   iwl6000-firmware.noarch 0:9.221.4.1-69.el7
#   iwl6000g2a-firmware.noarch 0:17.168.5.3-69.el7
#   iwl6000g2b-firmware.noarch 0:17.168.5.2-69.el7
#   iwl6050-firmware.noarch 0:41.28.5.1-69.el7
#   iwl7260-firmware.noarch 0:22.0.7.0-69.el7
#   iwl7265-firmware.noarch 0:22.0.7.0-69.el7
#   kbd.x86_64 0:1.15.5-15.el7
#   kbd-legacy.noarch 0:1.15.5-15.el7
#   kbd-misc.noarch 0:1.15.5-15.el7
#   kernel-debug-devel.x86_64 0:3.10.0-957.5.1.el7
#   kernel-headers.x86_64 0:3.10.0-957.5.1.el7
#   kernel-tools.x86_64 0:3.10.0-957.5.1.el7
#   kernel-tools-libs.x86_64 0:3.10.0-957.5.1.el7
#   kexec-tools.x86_64 0:2.0.15-21.el7
#   kmod.x86_64 0:20-23.el7
#   kmod-libs.x86_64 0:20-23.el7
#   kpartx.x86_64 0:0.4.9-123.el7
#   krb5-devel.x86_64 0:1.15.1-37.el7_6
#   krb5-libs.x86_64 0:1.15.1-37.el7_6
#   libX11.x86_64 0:1.6.5-2.el7
#   libX11-common.noarch 0:1.6.5-2.el7
#   libX11-devel.x86_64 0:1.6.5-2.el7
#   libblkid.x86_64 0:2.23.2-59.el7
#   libcom_err.x86_64 0:1.42.9-13.el7
#   libcom_err-devel.x86_64 0:1.42.9-13.el7
#   libcroco.x86_64 0:0.6.12-4.el7
#   libcurl.x86_64 0:7.29.0-51.el7
#   libcurl-devel.x86_64 0:7.29.0-51.el7
#   libdrm.x86_64 0:2.4.91-3.el7
#   libdrm-devel.x86_64 0:2.4.91-3.el7
#   libfastjson.x86_64 0:0.99.4-3.el7
#   libgcc.x86_64 0:4.8.5-36.el7
#   libgfortran.x86_64 0:4.8.5-36.el7
#   libgomp.x86_64 0:4.8.5-36.el7
#   libicu.x86_64 0:50.1.2-17.el7
#   libjpeg-turbo.x86_64 0:1.2.90-6.el7
#   libkadm5.x86_64 0:1.15.1-37.el7_6
#   libmount.x86_64 0:2.23.2-59.el7
#   libquadmath.x86_64 0:4.8.5-36.el7
#   libquadmath-devel.x86_64 0:4.8.5-36.el7
#   libselinux.x86_64 0:2.5-14.1.el7
#   libselinux-devel.x86_64 0:2.5-14.1.el7
#   libselinux-python.x86_64 0:2.5-14.1.el7
#   libselinux-utils.x86_64 0:2.5-14.1.el7
#   libsemanage.x86_64 0:2.5-14.el7
#   libsepol.x86_64 0:2.5-10.el7
#   libsepol-devel.x86_64 0:2.5-10.el7
#   libss.x86_64 0:1.42.9-13.el7
#   libssh2.x86_64 0:1.4.3-12.el7
#   libstdc++.x86_64 0:4.8.5-36.el7
#   libstdc++-devel.x86_64 0:4.8.5-36.el7
#   libteam.x86_64 0:1.27-5.el7
#   libuuid.x86_64 0:2.23.2-59.el7
#   libuv.x86_64 1:1.26.0-1.el7
#   libwayland-client.x86_64 0:1.15.0-1.el7
#   libwayland-server.x86_64 0:1.15.0-1.el7
#   libxcb.x86_64 0:1.13-1.el7
#   libxcb-devel.x86_64 0:1.13-1.el7
#   linux-firmware.noarch 0:20180911-69.git85c5d90.el7
#   logrotate.x86_64 0:3.8.6-17.el7
#   lvm2.x86_64 7:2.02.180-10.el7_6.3
#   lvm2-libs.x86_64 7:2.02.180-10.el7_6.3
#   man-db.x86_64 0:2.6.3-11.el7
#   mariadb.x86_64 1:5.5.60-1.el7_5
#   mariadb-libs.x86_64 1:5.5.60-1.el7_5
#   mariadb-server.x86_64 1:5.5.60-1.el7_5
#   mesa-libEGL.x86_64 0:18.0.5-4.el7_6
#   mesa-libEGL-devel.x86_64 0:18.0.5-4.el7_6
#   mesa-libGL.x86_64 0:18.0.5-4.el7_6
#   mesa-libGL-devel.x86_64 0:18.0.5-4.el7_6
#   mesa-libgbm.x86_64 0:18.0.5-4.el7_6
#   mesa-libglapi.x86_64 0:18.0.5-4.el7_6
#   microcode_ctl.x86_64 2:2.1-47.el7
#   mokutil.x86_64 0:15-2.el7.centos
#   nodejs.x86_64 1:6.16.0-1.el7
#   npm.x86_64 1:3.10.10-1.6.16.0.1.el7
#   nss.x86_64 0:3.36.0-7.1.el7_6
#   nss-pem.x86_64 0:1.0.3-5.el7
#   nss-sysinit.x86_64 0:3.36.0-7.1.el7_6
#   nss-tools.x86_64 0:3.36.0-7.1.el7_6
#   nss-util.x86_64 0:3.36.0-1.1.el7_6
#   openldap.x86_64 0:2.4.44-21.el7_6
#   openssl.x86_64 1:1.0.2k-16.el7
#   openssl-devel.x86_64 1:1.0.2k-16.el7
#   openssl-libs.x86_64 1:1.0.2k-16.el7
#   perl.x86_64 4:5.16.3-294.el7_6
#   perl-Git.noarch 0:1.8.3.1-20.el7
#   perl-Pod-Escapes.noarch 1:1.04-294.el7_6
#   perl-libs.x86_64 4:5.16.3-294.el7_6
#   perl-macros.x86_64 4:5.16.3-294.el7_6
#   php.x86_64 0:5.4.16-46.el7
#   php-cli.x86_64 0:5.4.16-46.el7
#   php-common.x86_64 0:5.4.16-46.el7
#   php-gd.x86_64 0:5.4.16-46.el7
#   php-ldap.x86_64 0:5.4.16-46.el7
#   php-mysql.x86_64 0:5.4.16-46.el7
#   php-pdo.x86_64 0:5.4.16-46.el7
#   policycoreutils.x86_64 0:2.5-29.el7_6.1
#   polkit.x86_64 0:0.112-18.el7_6.1
#   postfix.x86_64 2:2.10.1-7.el7
#   procps-ng.x86_64 0:3.3.10-23.el7
#   python.x86_64 0:2.7.5-76.el7
#   python-firewall.noarch 0:0.5.3-5.el7
#   python-libs.x86_64 0:2.7.5-76.el7
#   python-linux-procfs.noarch 0:0.4.9-4.el7
#   python-perf.x86_64 0:3.10.0-957.5.1.el7
#   python-rpm-macros.noarch 0:3-22.el7
#   python-srpm-macros.noarch 0:3-22.el7
#   python-urlgrabber.noarch 0:3.10-9.el7
#   python36.x86_64 0:3.6.6-2.el7
#   python36-devel.x86_64 0:3.6.6-2.el7
#   python36-libs.x86_64 0:3.6.6-2.el7
#   redhat-rpm-config.noarch 0:9.1.0-87.el7.centos
#   rpm.x86_64 0:4.11.3-35.el7
#   rpm-build.x86_64 0:4.11.3-35.el7
#   rpm-build-libs.x86_64 0:4.11.3-35.el7
#   rpm-libs.x86_64 0:4.11.3-35.el7
#   rpm-python.x86_64 0:4.11.3-35.el7
#   rpm-sign.x86_64 0:4.11.3-35.el7
#   rsyslog.x86_64 0:8.24.0-34.el7
#   selinux-policy.noarch 0:3.13.1-229.el7_6.9
#   selinux-policy-targeted.noarch 0:3.13.1-229.el7_6.9
#   setup.noarch 0:2.8.71-10.el7
#   shadow-utils.x86_64 2:4.1.5.1-25.el7
#   sudo.x86_64 0:1.8.23-3.el7
#   systemd.x86_64 0:219-62.el7_6.5
#   systemd-libs.x86_64 0:219-62.el7_6.5
#   systemd-sysv.x86_64 0:219-62.el7_6.5
#   systemtap.x86_64 0:3.3-3.el7
#   systemtap-client.x86_64 0:3.3-3.el7
#   systemtap-devel.x86_64 0:3.3-3.el7
#   systemtap-runtime.x86_64 0:3.3-3.el7
#   tar.x86_64 2:1.26-35.el7
#   teamd.x86_64 0:1.27-5.el7
#   tuned.noarch 0:2.10.0-6.el7
#   tzdata.noarch 0:2018i-1.el7
#   util-linux.x86_64 0:2.23.2-59.el7
#   vim-minimal.x86_64 2:7.4.160-5.el7
#   wget.x86_64 0:1.14-18.el7
#   wpa_supplicant.x86_64 1:2.6-12.el7
#   xfsprogs.x86_64 0:4.5.0-18.el7
#   xorg-x11-proto-devel.noarch 0:2018.4-1.el7
#   yum.noarch 0:3.4.3-161.el7.centos
#   yum-plugin-fastestmirror.noarch 0:1.1.31-50.el7
#   yum-utils.noarch 0:1.1.31-50.el7
#   zeromq.x86_64 0:4.1.4-6.el7
#   zeromq-devel.x86_64 0:4.1.4-6.el7
#   zlib.x86_64 0:1.2.7-18.el7
#   zlib-devel.x86_64 0:1.2.7-18.el7
#
# Sustituido(s):
#   grub2.x86_64 1:2.02-0.65.el7.centos.2
#   grub2-tools.x86_64 1:2.02-0.65.el7.centos.2
#
# ¡Listo!

# %% [markdown]
# Este contenido define el repositorio que se utilizará para instalar mongodb.
#
# La configuración debe de ser guardadan en */etc/yum.repos/mongo.repo*

# %%
[mongodb-org-3.4]
name=MongoDB Repository
baseurl=https://repo.mongodb.org/yum/redhat/$releasever/mongodb-org/3.4/x86_64/
gpgcheck=1
enabled=1
gpgkey=https://www.mongodb.org/static/pgp/server-3.4.asc

# %%
sudo yum repolist
# Out:
# Complementos cargados:fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: repos-tx.psychz.net
#  * epel: mirror.compevo.com
#  * extras: mirror.rackspace.com
#  * updates: mirror.atlantic.net
# mongodb-org-3.4                                          | 2.5 kB     00:00
# mongodb-org-3.4/7/primary_db                               |  84 kB   00:00
# id del repositorio     nombre del repositorio                             estado
# base/7/x86_64          CentOS-7 - Base                                    10 019
# epel/x86_64            Extra Packages for Enterprise Linux 7 - x86_64     12 981
# extras/7/x86_64        CentOS-7 - Extras                                     371
# mongodb-org-3.4/7      MongoDB Repository                                    105
# updates/7/x86_64       CentOS-7 - Updates                                  1 163
# repolist: 24 639

# %%
sudo yum update -y
# Out:
# Complementos cargados:fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: repos-tx.psychz.net
#  * epel: mirror.compevo.com
#  * extras: mirror.rackspace.com
#  * updates: mirror.atlantic.net
# No packages marked for update

# %%
sudo yum install mongodb-org -y
# Out:
# Complementos cargados:fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: repos-tx.psychz.net
#  * epel: mirror.compevo.com
#  * extras: mirror.rackspace.com
#  * updates: mirror.atlantic.net
# Resolviendo dependencias
# --> Ejecutando prueba de transacción
# ---> Paquete mongodb-org.x86_64 0:3.4.20-1.el7 debe ser instalado
# --> Procesando dependencias: mongodb-org-tools = 3.4.20 para el paquete: mongodb-org-3.4.20-1.el7.x86_64
# --> Procesando dependencias: mongodb-org-shell = 3.4.20 para el paquete: mongodb-org-3.4.20-1.el7.x86_64
# --> Procesando dependencias: mongodb-org-server = 3.4.20 para el paquete: mongodb-org-3.4.20-1.el7.x86_64
# --> Procesando dependencias: mongodb-org-mongos = 3.4.20 para el paquete: mongodb-org-3.4.20-1.el7.x86_64
# --> Ejecutando prueba de transacción
# ---> Paquete mongodb-org-mongos.x86_64 0:3.4.20-1.el7 debe ser instalado
# ---> Paquete mongodb-org-server.x86_64 0:3.4.20-1.el7 debe ser instalado
# ---> Paquete mongodb-org-shell.x86_64 0:3.4.20-1.el7 debe ser instalado
# ---> Paquete mongodb-org-tools.x86_64 0:3.4.20-1.el7 debe ser instalado
# --> Resolución de dependencias finalizada
#
# Dependencias resueltas
#
# ================================================================================
#  Package                Arquitectura
#                                    Versión            Repositorio         Tamaño
# ================================================================================
# Instalando:
#  mongodb-org            x86_64     3.4.20-1.el7       mongodb-org-3.4     5.8 k
# Instalando para las dependencias:
#  mongodb-org-mongos     x86_64     3.4.20-1.el7       mongodb-org-3.4      12 M
#  mongodb-org-server     x86_64     3.4.20-1.el7       mongodb-org-3.4      20 M
#  mongodb-org-shell      x86_64     3.4.20-1.el7       mongodb-org-3.4      11 M
#  mongodb-org-tools      x86_64     3.4.20-1.el7       mongodb-org-3.4      69 M
#
# Resumen de la transacción
# ================================================================================
# Instalar  1 Paquete (+4 Paquetes dependientes)
#
# Tamaño total de la descarga: 112 M
# Tamaño instalado: 286 M
# Downloading packages:
# advertencia:/var/cache/yum/x86_64/7/mongodb-org-3.4/packages/mongodb-org-3.4.20-1.el7.x86_64.rpm: EncabezadoV3 RSA/SHA1 Signature, ID de clave a15703c6: NOKEY
# No se ha instalado la llave pública de mongodb-org-3.4.20-1.el7.x86_64.rpm
# (1/5): mongodb-org-3.4.20-1.el7.x86_64.rpm                 | 5.8 kB   00:00
# (2/5): mongodb-org-mongos-3.4.20-1.el7.x86_64.rpm          |  12 MB   00:01
# (3/5): mongodb-org-shell-3.4.20-1.el7.x86_64.rpm           |  11 MB   00:01
# (4/5): mongodb-org-server-3.4.20-1.el7.x86_64.rpm          |  20 MB   00:03
# (5/5): mongodb-org-tools-3.4.20-1.el7.x86_64.rpm           |  69 MB   00:06
# --------------------------------------------------------------------------------
# Total                                               12 MB/s | 112 MB  00:09
# Obteniendo clave desde https://www.mongodb.org/static/pgp/server-3.4.asc
# Importando llave GPG 0xA15703C6:
#  Usuarioid  : "MongoDB 3.4 Release Signing Key <packaging@mongodb.com>"
#  Huella       : 0c49 f373 0359 a145 1858 5931 bc71 1f9b a157 03c6
#  Desde      : https://www.mongodb.org/static/pgp/server-3.4.asc
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
#   Instalando    : mongodb-org-shell-3.4.20-1.el7.x86_64                     1/5
#   Instalando    : mongodb-org-mongos-3.4.20-1.el7.x86_64                    2/5
#   Instalando    : mongodb-org-tools-3.4.20-1.el7.x86_64                     3/5
#   Instalando    : mongodb-org-server-3.4.20-1.el7.x86_64                    4/5
# Created symlink from /etc/systemd/system/multi-user.target.wants/mongod.service to /usr/lib/systemd/system/mongod.service.
#   Instalando    : mongodb-org-3.4.20-1.el7.x86_64                           5/5
#   Comprobando   : mongodb-org-3.4.20-1.el7.x86_64                           1/5
#   Comprobando   : mongodb-org-server-3.4.20-1.el7.x86_64                    2/5
#   Comprobando   : mongodb-org-tools-3.4.20-1.el7.x86_64                     3/5
#   Comprobando   : mongodb-org-mongos-3.4.20-1.el7.x86_64                    4/5
#   Comprobando   : mongodb-org-shell-3.4.20-1.el7.x86_64                     5/5
#
# Instalado:
#   mongodb-org.x86_64 0:3.4.20-1.el7
#
# Dependencia(s) instalada(s):
#   mongodb-org-mongos.x86_64 0:3.4.20-1.el7
#   mongodb-org-server.x86_64 0:3.4.20-1.el7
#   mongodb-org-shell.x86_64 0:3.4.20-1.el7
#   mongodb-org-tools.x86_64 0:3.4.20-1.el7
#
# ¡Listo!

# %%
sudo ls /lib/systemd/system/mongo*
# Out:
# /lib/systemd/system/mongod.service

# %%
sudo systemctl start mongod.service

# %%
sudo systemctl enable mongod.service

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2019.</p>
