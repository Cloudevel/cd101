# %% [markdown]
# [![cloudevel](img/cloudevel.png)](https://cloudevel.com)

# %% [markdown]
# # Fechas y temporizadores.

# %% [markdown]
# ## El comando ```date```.

# %%
date
# Out:
# Fri Jun  5 03:56:03 UTC 2020

# %%
date +%T
# Out:
# 04:09:09

# %%
date +%D
# Out:
# 06/05/20

# %%
date +%s
# Out:
# 1591330482

# %%
TZ='America/Los_Angeles' date
# Out:
# Thu Jun  4 21:06:07 PDT 2020

# %%
date -r LICENSE
# Out:
# Sat May 30 21:36:32 UTC 2020

# %%
date --date='@1587383647'
# Out:
# Mon Apr 20 11:54:07 UTC 2020

# %% [markdown]
# ### La *manpage* de ```date```.

# %%
man date
# Out:
# DATE(1)                          User Commands                         DATE(1)
#
# NAME
#        date - print or set the system date and time
#
# SYNOPSIS
#        date [OPTION]... [+FORMAT]
#        date [-u|--utc|--universal] [MMDDhhmm[[CC]YY][.ss]]
#
# DESCRIPTION
#        Display the current time in the given FORMAT, or set the system date.
#
#        Mandatory  arguments  to  long  options are mandatory for short options
#        too.
#
#        -d, --date=STRING
#               display time described by STRING, not 'now'
#
#        --debug
#               annotate the parsed date, and warn about questionable  usage  to
#               stderr
#
#        -f, --file=DATEFILE
#               like --date; once for each line of DATEFILE
#
#        -I[FMT], --iso-8601[=FMT]
#               output  date/time  in ISO 8601 format.  FMT='date' for date only
#               (the default), 'hours', 'minutes', 'seconds', or 'ns'  for  date
#               and    time    to    the    indicated    precision.     Example:
#               2006-08-14T02:34:56-06:00
#
#        -R, --rfc-email
#               output date and time in RFC 5322 format.  Example: Mon,  14  Aug
#               2006 02:34:56 -0600
#
#        --rfc-3339=FMT
#               output  date/time in RFC 3339 format.  FMT='date', 'seconds', or
#               'ns' for date and time to  the  indicated  precision.   Example:
#               2006-08-14 02:34:56-06:00
#
#        -r, --reference=FILE
#               display the last modification time of FILE
#
#        -s, --set=STRING
#               set time described by STRING
#
#        -u, --utc, --universal
#               print or set Coordinated Universal Time (UTC)
#
#        --help display this help and exit
#
#        --version
#               output version information and exit
#
#        FORMAT controls the output.  Interpreted sequences are:
#
#        %%     a literal %
#
#        %a     locale's abbreviated weekday name (e.g., Sun)
#
#        %A     locale's full weekday name (e.g., Sunday)
#
#        %b     locale's abbreviated month name (e.g., Jan)
#
#        %B     locale's full month name (e.g., January)
#
#        %c     locale's date and time (e.g., Thu Mar  3 23:05:25 2005)
#
#        %C     century; like %Y, except omit last two digits (e.g., 20)
#
#        %d     day of month (e.g., 01)
#
#        %D     date; same as %m/%d/%y
#
#        %e     day of month, space padded; same as %_d
#
#        %F     full date; same as %Y-%m-%d
#
#        %g     last two digits of year of ISO week number (see %G)
#
#        %G     year of ISO week number (see %V); normally useful only with %V
#
#        %h     same as %b
#
#        %H     hour (00..23)
#
#        %I     hour (01..12)
#
#        %j     day of year (001..366)
#
#        %k     hour, space padded ( 0..23); same as %_H
#
#        %l     hour, space padded ( 1..12); same as %_I
#
#        %m     month (01..12)
#
#        %M     minute (00..59)
#
#        %n     a newline
#
#        %N     nanoseconds (000000000..999999999)
#
#        %p     locale's equivalent of either AM or PM; blank if not known
#
#        %P     like %p, but lower case
#
#        %q     quarter of year (1..4)
#
#        %r     locale's 12-hour clock time (e.g., 11:11:04 PM)
#
#        %R     24-hour hour and minute; same as %H:%M
#
#        %s     seconds since 1970-01-01 00:00:00 UTC
#
#        %S     second (00..60)
#
#        %t     a tab
#
#        %T     time; same as %H:%M:%S
#
#        %u     day of week (1..7); 1 is Monday
#
#        %U     week number of year, with Sunday as first day of week (00..53)
#
#        %V     ISO week number, with Monday as first day of week (01..53)
#
#        %w     day of week (0..6); 0 is Sunday
#
#        %W     week number of year, with Monday as first day of week (00..53)
#
#        %x     locale's date representation (e.g., 12/31/99)
#
#        %X     locale's time representation (e.g., 23:13:48)
#
#        %y     last two digits of year (00..99)
#
#        %Y     year
#
#        %z     +hhmm numeric time zone (e.g., -0400)
#
#        %:z    +hh:mm numeric time zone (e.g., -04:00)
#
#        %::z   +hh:mm:ss numeric time zone (e.g., -04:00:00)
#
#        %:::z  numeric  time  zone  with  :  to necessary precision (e.g., -04,
#               +05:30)
#
#        %Z     alphabetic time zone abbreviation (e.g., EDT)
#
#        By default, date pads numeric fields with zeroes.   The  following  op‐
#        tional flags may follow '%':
#
#        -      (hyphen) do not pad the field
#
#        _      (underscore) pad with spaces
#
#        0      (zero) pad with zeros
#
#        ^      use upper case if possible
#
#        #      use opposite case if possible
#
#        After  any  flags  comes  an optional field width, as a decimal number;
#        then an optional modifier, which is either E to use the locale's alter‐
#        nate  representations  if available, or O to use the locale's alternate
#        numeric symbols if available.
#
# EXAMPLES
#        Convert seconds since the epoch (1970-01-01 UTC) to a date
#
#               $ date --date='@2147483647'
#
#        Show the time on the west coast of the US (use tzselect(1) to find TZ)
#
#               $ TZ='America/Los_Angeles' date
#
#        Show the local time for 9AM next Friday on the west coast of the US
#
#               $ date --date='TZ="America/Los_Angeles" 09:00 next Fri'
#
# DATE STRING
#        The --date=STRING is a mostly free format human  readable  date  string
#        such  as  "Sun, 29 Feb 2004 16:21:42 -0800" or "2004-02-29 16:21:42" or
#        even "next Thursday".  A date string may contain items indicating  cal‐
#        endar  date,  time of day, time zone, day of week, relative time, rela‐
#        tive date, and numbers.  An empty string indicates the beginning of the
#        day.   The date string format is more complex than is easily documented
#        here but is fully described in the info documentation.
#
# AUTHOR
#        Written by David MacKenzie.
#
# REPORTING BUGS
#        GNU coreutils online help: <https://www.gnu.org/software/coreutils/>
#        Report date translation bugs to <https://translationproject.org/team/>
#
# COPYRIGHT
#        Copyright © 2018 Free Software Foundation, Inc.   License  GPLv3+:  GNU
#        GPL version 3 or later <https://gnu.org/licenses/gpl.html>.
#        This  is  free  software:  you  are free to change and redistribute it.
#        There is NO WARRANTY, to the extent permitted by law.
#
# SEE ALSO
#        Full documentation at: <https://www.gnu.org/software/coreutils/date>
#        or available locally via: info '(coreutils) date invocation'
#
# GNU coreutils 8.30              September 2019                         DATE(1)

# %% [markdown]
# ## El comando ```time```.

# %%
time du /home
# Out:
# 16	/home/cloudevel
# 4	/home/oi/.theia/globalStorage
# 4	/home/oi/.theia/workspace-storage/5ad988e17539f4b18908b6440eb80621
# 8	/home/oi/.theia/workspace-storage
# 4	/home/oi/.theia/logs/20200528T181440/host
# 8	/home/oi/.theia/logs/20200528T181440
# 12	/home/oi/.theia/logs
# 4	/home/oi/.theia/plugin-storage
# 40	/home/oi/.theia
# 4	/home/oi/directorio con espacios
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86_64
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/BSD-x86
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x32
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin-i386-cc
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/darwin64-x86_64-cc
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64-ARM/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64-ARM/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64-ARM/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64-ARM/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64-ARM/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64-ARM/no-asm
# 68	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64-ARM
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux32-s390x
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix-gcc
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN64A
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-armv4
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-s390x
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris64-x86_64-gcc
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-x86_64
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc64le
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-aarch64
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/aix64-gcc
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-elf
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux-ppc
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/VC-WIN32
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/linux64-mips64
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm_avx2/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm_avx2/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm_avx2/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm_avx2/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm_avx2/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm_avx2
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/asm
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/no-asm/crypto/include/internal
# 16	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/no-asm/crypto/include
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/no-asm/crypto
# 12	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/no-asm/include/openssl
# 36	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/no-asm/include
# 64	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc/no-asm
# 196	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs/solaris-x86-gcc
# 4188	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl/archs
# 5784	/home/oi/.cache/node-gyp/10.20.1/include/node/openssl
# 24	/home/oi/.cache/node-gyp/10.20.1/include/node/libplatform
# 168	/home/oi/.cache/node-gyp/10.20.1/include/node/uv
# 6736	/home/oi/.cache/node-gyp/10.20.1/include/node
# 6740	/home/oi/.cache/node-gyp/10.20.1/include
# 6748	/home/oi/.cache/node-gyp/10.20.1
# 6752	/home/oi/.cache/node-gyp
# 28	/home/oi/.cache/yarn/v6/npm-nan-2.14.1-d7be34dfa3105b91494c3147089315eff8874b01-integrity/node_modules/nan/tools
# 152	/home/oi/.cache/yarn/v6/npm-nan-2.14.1-d7be34dfa3105b91494c3147089315eff8874b01-integrity/node_modules/nan/doc
# 628	/home/oi/.cache/yarn/v6/npm-nan-2.14.1-d7be34dfa3105b91494c3147089315eff8874b01-integrity/node_modules/nan
# 8	/home/oi/.npm/_cacache/content-v2/sha1/e0/e6
# 12	/home/oi/.npm/_cacache/content-v2/sha1/e0
# 8	/home/oi/.npm/_cacache/content-v2/sha1/45/0d
# 12	/home/oi/.npm/_cacache/content-v2/sha1/45
# 8	/home/oi/.npm/_cacache/content-v2/sha1/3d/7c
# 12	/home/oi/.npm/_cacache/content-v2/sha1/3d
# 8	/home/oi/.npm/_cacache/content-v2/sha1/97/fb
# 12	/home/oi/.npm/_cacache/content-v2/sha1/97
# 8	/home/oi/.npm/_cacache/content-v2/sha1/c3/b3
# 12	/home/oi/.npm/_cacache/content-v2/sha1/c3
# 8	/home/oi/.npm/_cacache/content-v2/sha1/94/a2
# 12	/home/oi/.npm/_cacache/content-v2/sha1/94
# 8	/home/oi/.npm/_cacache/content-v2/sha1/0d/07
# 12	/home/oi/.npm/_cacache/content-v2/sha1/0d
# 12	/home/oi/.npm/_cacache/content-v2/sha1/fa/13
# 16	/home/oi/.npm/_cacache/content-v2/sha1/fa
# 8	/home/oi/.npm/_cacache/content-v2/sha1/6a/38
# 12	/home/oi/.npm/_cacache/content-v2/sha1/6a
# 8	/home/oi/.npm/_cacache/content-v2/sha1/73/44
# 12	/home/oi/.npm/_cacache/content-v2/sha1/73
# 8	/home/oi/.npm/_cacache/content-v2/sha1/b5/24
# 12	/home/oi/.npm/_cacache/content-v2/sha1/b5/fd
# 24	/home/oi/.npm/_cacache/content-v2/sha1/b5
# 8	/home/oi/.npm/_cacache/content-v2/sha1/84/c6
# 12	/home/oi/.npm/_cacache/content-v2/sha1/84
# 8	/home/oi/.npm/_cacache/content-v2/sha1/ef/9e
# 12	/home/oi/.npm/_cacache/content-v2/sha1/ef
# 312	/home/oi/.npm/_cacache/content-v2/sha1
# 4332	/home/oi/.npm/_cacache/content-v2
# 6508	/home/oi/.npm/_cacache
# 4	/home/oi/.npm/_locks
# 304	/home/oi/.npm/_prebuilds
# 6824	/home/oi/.npm
# 1474108	/home/oi
# 16	/home/josech
# 1474144	/home
#
# real	0m14.588s
# user	0m0.346s
# sys	0m2.347s

# %%
man time
# Out:
# TIME(1)                     General Commands Manual                    TIME(1)
#
# NAME
#        time - run programs and summarize system resource usage
#
# SYNOPSIS
#        time   [ -apqvV ] [ -f FORMAT ] [ -o FILE ]
#               [ --append ] [ --verbose ] [ --quiet ] [ --portability ]
#               [ --format=FORMAT ] [ --output=FILE ] [ --version ]
#               [ --help ] COMMAND [ ARGS ]
#
# DESCRIPTION
#        time run the program COMMAND with any given arguments ARG....  When
#        COMMAND finishes, time displays information about resources used by
#        COMMAND (on the standard error output, by default).  If COMMAND exits
#        with non-zero status, time displays a warning message and the exit
#        status.
#
#        time determines which information to display about the resources used
#        by the COMMAND from the string FORMAT.  If no format is specified on
#        the command line, but the TIME environment variable is set, its value
#        is used as the format.  Otherwise, a default format built into time is
#        used.
#
#        Options to time must appear on the command line before COMMAND.
#        Anything on the command line after COMMAND is passed as arguments to
#        COMMAND.
#
# OPTIONS
#        -o FILE, --output=FILE
#               Write the resource use statistics to FILE instead of to the
#               standard error stream.  By default, this overwrites the file,
#               destroying the file's previous contents.  This option is useful
#               for collecting information on interactive programs and programs
#               that produce output on the standard error stream.
#
#        -a, --append
#               Append the resource use information to the output file instead
#               of overwriting it.  This option is only useful with the `-o' or
#               `--output' option.
#
#        -f FORMAT, --format FORMAT
#               Use FORMAT as the format string that controls the output of
#               time.  See the below more information.
#
#        --help Print a summary of the command line options and exit.
#
#        -p, --portability
#               Use the following format string, for conformance with POSIX
#               standard 1003.2:
#                         real %e
#                         user %U
#                         sys %S
#
#        -v, --verbose
#               Use the built-in verbose format, which displays each available
#               piece of information on the program's resource use on its own
#               line, with an English description of its meaning.
#
#        --quiet
#               Do not report the status of the program even if it is different
#               from zero.
#
#        -V, --version
#               Print the version number of time and exit.
#
# FORMATTING THE OUTPUT
#        The format string FORMAT controls the contents of the time output.  The
#        format string can be set using the `-f' or `--format', `-v' or
#        `--verbose', or `-p' or `--portability' options.  If they are not
#        given, but the TIME environment variable is set, its value is used as
#        the format string.  Otherwise, a built-in default format is used.  The
#        default format is:
#          %Uuser %Ssystem %Eelapsed %PCPU (%Xtext+%Ddata %Mmax)k
#          %Iinputs+%Ooutputs (%Fmajor+%Rminor)pagefaults %Wswaps
#
#        The format string usually consists of `resource specifiers'
#        interspersed with plain text.  A percent sign (`%') in the format
#        string causes the following character to be interpreted as a resource
#        specifier, which is similar to the formatting characters in the
#        printf(3) function.
#
#        A backslash (`\') introduces a `backslash escape', which is translated
#        into a single printing character upon output.  `\t' outputs a tab
#        character, `\n' outputs a newline, and `\\' outputs a backslash.  A
#        backslash followed by any other character outputs a question mark (`?')
#        followed by a backslash, to indicate that an invalid backslash escape
#        was given.
#
#        Other text in the format string is copied verbatim to the output.  time
#        always prints a newline after printing the resource use information, so
#        normally format strings do not end with a newline character (or `\n').
#
#        There are many resource specifications.  Not all resources are measured
#        by all versions of Unix, so some of the values might be reported as
#        zero.  Any character following a percent sign that is not listed in the
#        table below causes a question mark (`?') to be output, followed by that
#        character, to indicate that an invalid resource specifier was given.
#
#        The resource specifiers, which are a superset of those recognized by
#        the tcsh(1) builtin `time' command, are:
#               %      A literal `%'.
#               C      Name and command line arguments of the command being
#                      timed.
#               D      Average size of the process's unshared data area, in
#                      Kilobytes.
#               E      Elapsed real (wall clock) time used by the process, in
#                      [hours:]minutes:seconds.
#               F      Number of major, or I/O-requiring, page faults that
#                      occurred while the process was running.  These are faults
#                      where the page has actually migrated out of primary
#                      memory.
#               I      Number of file system inputs by the process.
#               K      Average total (data+stack+text) memory use of the
#                      process, in Kilobytes.
#               M      Maximum resident set size of the process during its
#                      lifetime, in Kilobytes.
#               O      Number of file system outputs by the process.
#               P      Percentage of the CPU that this job got.  This is just
#                      user + system times divided by the total running time.
#                      It also prints a percentage sign.
#               R      Number of minor, or recoverable, page faults.  These are
#                      pages that are not valid (so they fault) but which have
#                      not yet been claimed by other virtual pages.  Thus the
#                      data in the page is still valid but the system tables
#                      must be updated.
#               S      Total number of CPU-seconds used by the system on behalf
#                      of the process (in kernel mode), in seconds.
#               U      Total number of CPU-seconds that the process used
#                      directly (in user mode), in seconds.
#               W      Number of times the process was swapped out of main
#                      memory.
#               X      Average amount of shared text in the process, in
#                      Kilobytes.
#               Z      System's page size, in bytes.  This is a per-system
#                      constant, but varies between systems.
#               c      Number of times the process was context-switched
#                      involuntarily (because the time slice expired).
#               e      Elapsed real (wall clock) time used by the process, in
#                      seconds.
#               k      Number of signals delivered to the process.
#               p      Average unshared stack size of the process, in Kilobytes.
#               r      Number of socket messages received by the process.
#               s      Number of socket messages sent by the process.
#               t      Average resident set size of the process, in Kilobytes.
#               w      Number of times that the program was context-switched
#                      voluntarily, for instance while waiting for an I/O
#                      operation to complete.
#               x      Exit status of the command.
#
# EXAMPLES
#        To run the command `wc /etc/hosts' and show the default information:
#             time wc /etc/hosts
#
#        To run the command `ls -Fs' and show just the user, system, and total
#        time:
#             time -f "\t%E real,\t%U user,\t%S sys" ls -Fs
#
#        To edit the file BORK and have `time' append the elapsed time and
#        number of signals to the file `log', reading the format string from the
#        environment variable `TIME':
#             export TIME="\t%E,\t%k" # If using bash or ksh
#             setenv TIME "\t%E,\t%k" # If using csh or tcsh
#             time -a -o log emacs bork
#
#        Users of the bash shell need to use an explicit path in order to run
#        the external time command and not the shell builtin variant.  On system
#        where time is installed in /usr/bin, the first example would become
#             /usr/bin/time wc /etc/hosts
#
# ACCURACY
#        The elapsed time is not collected atomically with the execution of the
#        program; as a result, in bizarre circumstances (if the time command
#        gets stopped or swapped out in between when the program being timed
#        exits and when time calculates how long it took to run), it could be
#        much larger than the actual execution time.
#
#        When the running time of a command is very nearly zero, some values
#        (e.g., the percentage of CPU used) may be reported as either zero
#        (which is wrong) or a question mark.
#
#        Most information shown by time is derived from the wait3(2) system
#        call.  The numbers are only as good as those returned by wait3(2).  On
#        systems that do not have a wait3(2) call that returns status
#        information, the times(2) system call is used instead.  However, it
#        provides much less information than wait3(2), so on those systems time
#        reports the majority of the resources as zero.
#
#        The `%I' and `%O' values are allegedly only `real' input and output and
#        do not include those supplied by caching devices.  The meaning of
#        `real' I/O reported by `%I' and `%O' may be muddled for workstations,
#        especially diskless ones.
#
# DIAGNOSTICS
#        The time command returns when the program exits, stops, or is
#        terminated by a signal.  If the program exited normally, the return
#        value of time is the return value of the program it executed and
#        measured.  Otherwise, the return value is 128 plus the number of the
#        signal which caused the program to stop or terminate.
# AUTHOR
#        time was written by David MacKenzie.  This man page was added by Dirk
#        Eddelbuettel <edd@debian.org>, the Debian GNU/Linux maintainer, for use
#        by the Debian GNU/Linux distribution but may of course be used by
#        others.
#
# SEE ALSO
#        tcsh(1), printf(3)
#
#                                Debian GNU/Linux                        TIME(1)

# %% [markdown]
# ## El comando ```at```.

# %%
man at
# Out:
# AT(1)                       General Commands Manual                      AT(1)
#
# NAME
#        at,  batch, atq, atrm - queue, examine, or delete jobs for later execu‐
#        tion
#
# SYNOPSIS
#        at [-V] [-q queue] [-f file] [-mMlv] timespec ...
#        at [-V] [-q queue] [-f file] [-mMkv] [-t time]
#        at -c job [...]
#        atq [-V] [-q queue]
#        at [-rd] job [...]
#        atrm [-V] job [...]
#        batch
#        at -b
#
# DESCRIPTION
#        at and batch read commands from standard  input  or  a  specified  file
#        which are to be executed at a later time, using /bin/sh.
#
#        at      executes commands at a specified time.
#
#        atq     lists  the  user's  pending  jobs, unless the user is the supe‐
#                ruser; in that case, everybody's jobs are listed.   The  format
#                of  the  output  lines (one for each job) is: Job number, date,
#                hour, queue, and username.
#
#        atrm    deletes jobs, identified by their job number.
#
#        batch   executes commands when system  load  levels  permit;  in  other
#                words,  when  the  load  average  drops below 1.5, or the value
#                specified in the invocation of atd.
#
#        At allows fairly complex time  specifications,  extending  the  POSIX.2
#        standard.   It  accepts  times of the form HH:MM to run a job at a spe‐
#        cific time of day.  (If that time is already past, the next day is  as‐
#        sumed.)   You may also specify midnight, noon, or teatime (4pm) and you
#        can have a time-of-day suffixed with AM or PM for running in the  morn‐
#        ing  or the evening.  You can also say what day the job will be run, by
#        giving a date in the form month-name day with an optional year, or giv‐
#        ing  a  date  of  the  form  MMDD[CC]YY,  MM/DD/[CC]YY, DD.MM.[CC]YY or
#        [CC]YY-MM-DD.  The specification of a date must follow  the  specifica‐
#        tion  of  the  time  of  day.  You can also give times like now + count
#        time-units, where the time-units can be minutes, hours, days, or  weeks
#        and you can tell at to run the job today by suffixing the time with to‐
#        day and to run the job tomorrow by suffixing the time with tomorrow.
#
#        For example, to run a job at 4pm three days from now, you would  do  at
#        4pm  + 3 days, to run a job at 10:00am on July 31, you would do at 10am
#        Jul 31 and to run a job at 1am tomorrow, you would do at 1am tomorrow.
#
#        If you specify a job to absolutely run at a specific time and  date  in
#        the  past, the job will run as soon as possible.  For example, if it is
#        8pm and you do a at 6pm today, it will run more likely at 8:05pm.
#
#        The  definition  of  the   time   specification   can   be   found   in
#        /usr/share/doc/at/timespec.
#
#        For  both  at  and  batch, commands are read from standard input or the
#        file specified with the -f option and executed.  The working directory,
#        the environment (except for the variables BASH_VERSINFO, DISPLAY, EUID,
#        GROUPS, SHELLOPTS, TERM, UID, and _) and the umask  are  retained  from
#        the time of invocation.
#
#        As  at  is currently implemented as a setuid program, other environment
#        variables (e.g., LD_LIBRARY_PATH or LD_PRELOAD) are also not  exported.
#        This  may  change  in the future.  As a workaround, set these variables
#        explicitly in your job.
#
#        An at - or batch - command invoked from a su(1) shell will  retain  the
#        current  userid.   The  user will be mailed standard error and standard
#        output from his commands, if any.  Mail will be sent using the  command
#        /usr/sbin/sendmail.  If at is executed from a su(1) shell, the owner of
#        the login shell will receive the mail.
#
#        The superuser may use these commands in any  case.   For  other  users,
#        permission  to  use  at  is  determined  by the files /etc/at.allow and
#        /etc/at.deny.  See at.allow(5) for details.
#
# OPTIONS
#        -V      prints the version number to standard error and  exit  success‐
#                fully.
#
#        -q queue
#                uses  the  specified  queue.  A queue designation consists of a
#                single letter; valid queue designations range from a to z and A
#                to  Z.   The  a queue is the default for at and the b queue for
#                batch.  Queues with higher letters run with increased niceness.
#                The  special queue "=" is reserved for jobs which are currently
#                running.
#
#        If a job is submitted to a queue designated with an  uppercase  letter,
#        the  job is treated as if it were submitted to batch at the time of the
#        job.  Once the time is reached, the batch processing rules with respect
#        to  load average apply.  If atq is given a specific queue, it will only
#        show jobs pending in that queue.
#
#        -m      Send mail to the user when the job has completed even if  there
#                was no output.
#
#        -M      Never send mail to the user.
#
#        -f file Reads the job from file rather than standard input.
#
#        -t time run the job at time, given in the format [[CC]YY]MMDDhhmm[.ss]
#
#        -l      Is an alias for atq.
#
#        -r      Is an alias for atrm.
#
#        -d      Is an alias for atrm.
#
#        -b      is an alias for batch.
#
#        -v      Shows the time the job will be executed before reading the job.
#
#        Times displayed will be in the format "Thu Feb 20 14:50:00 1997".
#
#        -c     cats the jobs listed on the command line to standard output.
#
# FILES
#        /var/spool/cron/atjobs
#        /var/spool/cron/atspool
#        /proc/loadavg
#        /var/run/utmp
#        /etc/at.allow
#        /etc/at.deny
#
# SEE ALSO
#        at.allow(5), at.deny(5), atd(8), cron(1), nice(1), sh(1), umask(2).
#
# BUGS
#        The  correct  operation of batch for Linux depends on the presence of a
#        proc- type directory mounted on /proc.
#
#        If the file /var/run/utmp is not available or corrupted, or if the user
#        is  not  logged  on  at the time at is invoked, the mail is sent to the
#        userid found in the environment variable LOGNAME.  If that is undefined
#        or empty, the current userid is assumed.
#
#        At  and  batch as presently implemented are not suitable when users are
#        competing for resources.  If this is the case for your site, you  might
#        want to consider another batch system, such as nqs.
#
# AUTHOR
#        At was mostly written by Thomas Koenig.
#
#                                   2009-11-14                             AT(1)

# %% [markdown]
# ## Temporizadores.
#
# Un temporizador (scheduler) en la tradición de UNIX y GNU/Linux es un daemon que ejecuta tareas preestablecidas en intervalos de tiempo definidos.
#
# El uso de los temporizadores permite realizar diversas acciones repetitivas sin la necesidad de ser ejecutadas manualmente.
#
# Aún cuando existen varios temporizadores para UNIX y GNU/Linux, los más común es ```cron```.

# %% [markdown]
# ## El daemon  ```crond```.
#
# Los temporizadores están ligados a un daemon el cual se encarga de ejecutar los comandos indicados a la hora definida.

# %% [markdown]
# **Ejemplo:**
#
# En el caso de es que esta notebook sea ejecutada desde la máquina virtual proporcionada por Cloudevel<sup>®</sup>, es posible conocer el estado del servicio mediante la siguiente instrucción.

# %%
sudo systemctl status cron --no-pager

# %% [markdown]
# ### Los archivos *crontab*.
#
# Las tablas de cron o "crontabs" son archivos de texto que contienen una serie de líneas que decriben la ejecución de un comando específico en un tiempo determinado.
#
# Cada línea del archivo crontab se apegarse al siguiente formato:
#
# ```
# * * * * * comando(s)
# - - - - -
# | | | | |
# | | | | ----- Día de la semana (0 - 7) (Sunday=0 or 7)
# | | | ------- Mes (1 - 12)
# | | --------- Día del mes(1 - 31)
# | ----------- Hora (0 - 23)
# ------------- Minutos (0 - 59)
# ```
#
# Cuando se utiliza el asterisco * , se está haciendo la indicación de que el comando aplica a todas las opciones de tiempo correspondientes.
#
# Los archivos *crontab* se localizan en el directorio */var/spool/cron/*

# %%
sudo ls /var/spool/cron

# %% [markdown]
# **Ejemplo:**
#
# La siguiente línea:
#
# ```
# 30   3    *    *    1 yum update
# ```
#
# Indica que se ejecutará el comando ```yum update``` cada lunes a las 3:30 horas.

# %% [markdown]
# ### El comando ```crontab```.
#
# No se recomienda editar los archivos *crontab* directamente. El comando ```crontab``` permite manipular un  archivo de este tipo para el usuario actual en caso de que cuente con los permisos para realizar estas operaciones.
#
# ```
# crontab <opciones> <argumentos>
# ```
# Las principales opciones de este comando son:
#
# * ```-e``` permite editar un archivo crontab para el usuario actual. En caso de que no exista, se creará un archivo temporal.
# * ```-l``` enlista el contendo del archivo crontab del usuario.
# * ```-r``` elimina el archivo crontab.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda desplegará el contenido del archivo *crontab* del usuario actual.
#
# Si no existe un archivo para el usuario, este no desplegará nada.

# %%
crontab -l

# %% [markdown]
# * Ejecute el comando ```crontab -e``` desde una terminal y añada la siguiente línea:
#
# ```25 16 * * * echo "Saludos" >> ~/saludos.txt```
#
# Lo anterior hará que el texto *Saludos" sea añadido al archivo *~/saludos.txt* a las 14:25 horas diariamente.

# %%
crontab -l

# %%
ls ~/saludos.txt

# %%
cat ~/saludos.txt

# %% [markdown]
# * La siguiente celda elimininará el crontab del usuario actual.

# %%
crontab -r

# %%
crontab -l

# %% [markdown]
# ## Archivos y directorios relevantes de ```crond```.
#
# El daemon ```crond``` cuenta con algunos archivos que pueden ser utilizados por *root*.
#
# ### Archivos de permisos.
#
# Los suguientes archivos delimitan a los usuarios que pueden o no utilizar crear *crontabs*.
#
# * */etc/cron.allow* contiene una lista de los usuarios autorizados.
# * */etc/cron.deny* contiene una lista de los usuarios autorizados.

# %%
sudo ls /etc/cron.deny

# %%
sudo ls /etc/cron.deny

# %%
sudo ls /etc/cron.allow

# %% [markdown]
# ### Archivos de administración.
#
# Estos archivos contienen una serie de comandos que pueden ser ejecutados en un momento específico.
#
# * */etc/cron.hourly* se ejecutarán en el primer segundo del primer minuto de cada hora.
# * */etc/cron.daily* se jejecutarán en el primer segundo de un día, diarimante.
# * */etc/cron.monthly* se ejecutarán en el primer segundo del primer día del mes, mensualmente.

# %%
ls /etc/cron.*

# %% [markdown]
# ### Bitácoras de cron.
#
# El archivo *var/log/cron* contiene la bitácora de todas las acciones del ```crond```.

# %%
sudo cat /var/log/cron

# %%
cat /etc/crontab

# %% [markdown]
# ## El comndo ```at```

# %% [markdown]
# ### La *manpage* de ```at```.

# %%
man at

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2020.</p>
