# %% [markdown]
# [![cloudevel](img/cloudevel.png)](https://cloudevel.com)

# %% [markdown]
# # Introducción a *Bash* scripting.

# %% [markdown]
# ## Variables de entorno.
#
# Una variable de entorno se define para tods los procesos de un usuario en una sesión.
#
# Las variables de entorno se definen mendiante el comando ```export```.

# %% [markdown]
# Si no se añade ningún argumento, ```export``` regresará la listade variables de entorno.

# %%
export

# %%
export NOMBRE=Jose

# %%
export LANG="es_MX"

# %%
export DEITY=Ala

# %%
export

# %% [markdown]
# ### Archivos de configuración de entorno.
#
# Estos archivos se encuentran el el home del usuario y se jecutan automáticamente cada vez que un usuario accede al sistema.
#
# * ~/.bashrc
# * ~/bash_profile
# * ~/.bash_logout
# * ~/.bash_history

# %%
cat ~/.bashrc

# %%
cat ~/.bash_profile

# %%
cat ~/.bash_logout

# %%
cat ~/.bash_history

# %% [markdown]
# ## El directorio */etc/skel*.
#
# Este directorio contiene los archivos de configuración de entorno que ser'na usados por defecto al crear un nuevo usuario.

# %%
ls -a /etc/skel

# %% [markdown]
# https://www.gnu.org/software/bash/manual/

# %% [markdown]
# ## El comando ```export```.

# %%
VAR=HOLA

# %%
export VAR=HOLA

# %% [markdown]
# ## El comando ```source```.

# %%
src/argumentos.sh argumentos
# Out:
# ingresaste 1 argumentos.
# Este es el argumento 1 argumentos

# %%
echo $NUMERO

# %%
source src/argumentos.sh argumentos
# Out:
# ingresaste 1 argumentos.
# Este es el argumento 1 argumentos

# %%
echo $NUMERO
# Out:
# 1

# %% [markdown]
# ## El comando ```alias```.

# %% [markdown]
# ## La historia.

# %% [markdown]
# ## El comando ```history```.

# %%
history
# Out:
#  1021  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1022  find . *.ipynb
#  1023  echo $?
#  1024  find . *.ipynb -maxdepth 1
#  1025  echo $?
#  1026  find . *.ipynb -maxdepth 2
#  1027  echo $?
#  1028  find . -iname '*.ipynb' -print
#  1029  echo $?
#  1030  find . -iname '*.ipynb' -exec  wc {} \;
#  1031  echo $?
#  1032  find . -maxdepth 1 -type d -exec ls {} +
#  1033  echo $?
#  1034  find .  -iname '*.ipynb' -exec cat {} \; | grep -i 'gnu/linux'
#  1035  echo $?
#  1036  man find
#  1037  echo $?
#  1038  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  1039  export PAGER=cat
#  1040  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1041  ls
#  1042  echo $?
#  1043  ls | xargs wc
#  1044  echo $?
#  1045  find . -iname '*.ipynb' -exec  wc {} | cut -f1 \;
#  1046  echo $?
#  1047  find . -iname '*.ipynb' -exec  wc {} | cut -f1; \;
#  1048  echo $?
#  1049  find . -iname '*.ipynb' -exec  wc {} | cut -f1\;
#  1050  echo $?
#  1051  find . -iname '*.ipynb' -exec  wc {} | cut -f1; \;
#  1052  echo $?
#  1053  find . -iname '*.ipynb' -exec  wc {} | cut -f1\;
#  1054  echo $?
#  1055  find . -iname '*.ipynb' -exec  wc {} | cut -f1 \;
#  1056  echo $?
#  1057  find . -iname '*.ipynb' -exec  "wc {} | cut -f1" \;
#  1058  echo $?
#  1059  find . -iname '*.ipynb' -exec  wc {} \;
#  1060  echo $?
#  1061  find . -iname '*.ipynb' -ok  wc {} \
#  1062  locate
#  1063  exit
#  1064  sudo fsck.ext4 /dev/ubuntu-vg/ubuntu-lv
#  1065  tune2fs -l /dev/ubuntu-vg/ubuntu-lv
#  1066  sudo tune2fs -l /dev/ubuntu-vg/ubuntu-lv
#  1067  cd cd101/
#  1068  git add --all
#  1069  git commit -m 200604a
#  1070  git push origin master
#  1071  exit
#  1072  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  1073  export PAGER=cat
#  1074  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1075  compgen -cdfa 05_
#  1076  find . *.ipynb -newer 05_jerarquía_de_directorios.ipynb
#  1077  echo $?
#  1078  find . *.ipynb -newer 05_jerarquía_de_directorios.ipynb -maxdepth 1
#  1079  echo $?
#  1080  find . *.ipynb -maxdepth 1 -newer 05_jerarquía_de_directorios.ipynb
#  1081  echo $?
#  1082  chmod +x saluda.sh
#  1083  echo $?
#  1084  find . -maxdepth 1 -executable
#  1085  echo $?
#  1086  find . -maxdepth 1 -fstype d
#  1087  echo $?
#  1088  find . -maxdepth 1 -fstype d
#  1089  echo $?
#  1090  find ~ -maxdepth 1 -links
#  1091  echo $?
#  1092  find . -iname '*.ipynb' -exec  wc {} \;
#  1093  echo $?
#  1094  find . -iname '*.ipynb' -exec  wc {} | sort \;
#  1095  echo $?
#  1096  find . -iname '*.ipynb' -exec  wc {} \; | sort
#  1097  echo $?
#  1098  find . -iname '*.ipynb' -exec  wc {} -l \;
#  1099  echo $?
#  1100  find /var -user www-data
#  1101  echo $?
#  1102  compgen -cdfa sa
#  1103  chgrp root saluda.sh
#  1104  echo $?
#  1105  chown oi:root saluda.sh
#  1106  echo $?
#  1107  echo "/bin/bash
#  1108  echo Hola, mundo." > saluda.sh
#  1109  echo $?
#  1110  chmod +x saluda.sh
#  1111  echo $?
#  1112  compgen -cdfa sal
#  1113  ls -l saluda.sh
#  1114  echo $?
#  1115  find . -excutable
#  1116  echo $?
#  1117  find . -executable
#  1118  echo $?
#  1119  find . -maxdepth 1 -executable
#  1120  echo $?
#  1121  compgen -cdfa sal
#  1122  chown oi:root saluda.sh
#  1123  echo $?
#  1124  sudo chown oi:root saluda.sh
#  1125  echo $?
#  1126  compgen -cdfa sal
#  1127  ls -l saluda.sh
#  1128  echo $?
#  1129  find . -maxdepth 1 -uid 1
#  1130  echo $?
#  1131  find . -maxdepth 1 -uid 1000
#  1132  echo $?
#  1133  find . maxdepth 1 -group root
#  1134  echo $?
#  1135  find . -maxdepth 1 -group root
#  1136  echo $?
#  1137  find . -maxdepth 1 -iname bash
#  1138  echo $?
#  1139  find . -maxdepth 1 -iname *bash*
#  1140  echo $?
#  1141  find . -maxdepth 1 -ipath *it*
#  1142  echo $?
#  1143  find . -maxdepth 1 -ipath .*it*
#  1144  echo $?
#  1145  find . -maxdepth 1 -ipath ".*it*"
#  1146  echo $?
#  1147  find . -ipath ".*it*"
#  1148  echo $?
#  1149  find . -ipath "*CH*"
#  1150  echo $?
#  1151  find . -ipath "*CH*/"
#  1152  echo $?
#  1153  find . -ipath "*CH*"
#  1154  echo $?
#  1155  find . -ipath "/*CH*"
#  1156  echo $?
#  1157  find . -ipath "/*CH*"
#  1158  echo $?
#  1159  find . -path "/*CH*"
#  1160  echo $?
#  1161  find . -path "*CH*"
#  1162  echo $?
#  1163  find . -path "*CH*"
#  1164  echo $?
#  1165  find . -maxdepth 1 -uid 1000 | sort
#  1166  echo $?
#  1167  find . -iregex "MIT"
#  1168  echo $?
#  1169  find . -iregex "^?[]"
#  1170  echo $?
#  1171  find . -iregex "^?[1]"
#  1172  echo $?
#  1173  find . -iregex "^?[1]*"
#  1174  echo $?
#  1175  find . -iregex "^[12]*"
#  1176  echo $?
#  1177  find . -iregex "[12]*"
#  1178  echo $?
#  1179  find . -iregex "[12]"
#  1180  echo $?
#  1181  find . -regex "[12]"
#  1182  echo $?
#  1183  find . -regex "[12]*"
#  1184  echo $?
#  1185  find . -regex "*"
#  1186  echo $?
#  1187  find . -regex "\*.png"
#  1188  echo $?
#  1189  find . -regex-type egrep -regex "\*.png"
#  1190  echo $?
#  1191  find . -regextype egrep -regex "\*.png"
#  1192  echo $?
#  1193  find . -regextype egrep -regex "*.png"
#  1194  echo $?
#  1195  find . -regextype egrep -regex "/*.png"
#  1196  echo $?
#  1197  find . -regextype egrep -regex "/*/.png"
#  1198  echo $?
#  1199  find . -regextype egrep -regex '/*/.png'
#  1200  echo $?
#  1201  find . -regextype egrep -regex '*.ng'
#  1202  echo $?
#  1203  find . -regextype grep -iegex '*.ng'
#  1204  echo $?
#  1205  find . -regextype grep -iregex '*.ng'
#  1206  echo $?
#  1207  find . -regextype grep -iregex '*ng$'
#  1208  echo $?
#  1209  find . -regextype zgrep -iregex '*ng$'
#  1210  echo $?
#  1211  find . -regextype grep -iregex '*ng$'
#  1212  echo $?
#  1213  find . -regextype grep -iregex '*'
#  1214  echo $?
#  1215  find . -regextype grep -iregex *
#  1216  echo $?
#  1217  find . -regextype grep -iregex '[12][2-5]*'
#  1218  echo $?
#  1219  find . -regextype grep -iregex '[12][2-5]*'
#  1220  echo $?
#  1221  ls '[12][2-5]*'
#  1222  echo $?
#  1223  ls [12][2-5]*
#  1224  echo $?
#  1225  ls | igrep [12][2-5]*
#  1226  echo $?
#  1227  ls | grep [12][2-5]*
#  1228  echo $?
#  1229  ls | grep [12][2-5]*
#  1230  echo $?
#  1231  ls | grep *
#  1232  echo $?
#  1233  ls | grep '[1][2]'
#  1234  echo $?
#  1235  ls | grep '[12][2]'
#  1236  echo $?
#  1237  ls | grep '[12][2-5]'
#  1238  echo $?
#  1239  find . regextype grep -regex '[12][2-5]'
#  1240  echo $?
#  1241  find . -regextype grep -regex '[12][2-5]'
#  1242  echo $?
#  1243  find . -regextype grep -regex '^[12][2-5]'
#  1244  echo $?
#  1245  ls  grep -regex '^[12][2-5]'
#  1246  echo $?
#  1247  ls | grep '^[12][2-5]'
#  1248  echo $?
#  1249  find .  regex '^[12][2-5]'
#  1250  echo $?
#  1251  find .  -regex '^[12][2-5]'
#  1252  echo $?
#  1253  find .  -regex './^[12][2-5]'
#  1254  echo $?
#  1255  find .  -regex '\./^[12][2-5]'
#  1256  echo $?
#  1257  find . -regextype egrep -regex '\./^[12][2-5]'
#  1258  echo $?
#  1259  find . -regextype egrep -regex '\./[12][2-5]'
#  1260  echo $?
#  1261  find . -regextype egrep -regex './[12][2-5]'
#  1262  echo $?
#  1263  find . -regextype egrep -regex '\./[12][2-5]'
#  1264  echo $?
#  1265  find -regextype posix-extended -regex '.*\.(jpg|png)'
#  1266  echo $?
#  1267  find -regextype posix-extended -regex '[12][2-47]'
#  1268  echo $?
#  1269  find -regextype posix-extended -regex '[12][27]'
#  1270  echo $?
#  1271  find -regextype posix-extended -regex '[12][27]*'
#  1272  echo $?
#  1273  find -regextype posix-extended -regex '.*\.(jpg|png)'
#  1274  echo $?
#  1275  find -regextype posix-extended -regex '.*(jpg|png)'
#  1276  echo $?
#  1277  find -regextype posix-extended -regex '.[23]*(jpg|png)'
#  1278  echo $?
#  1279  find -regextype posix-extended -regex '.*(jpg|png)'
#  1280  echo $?
#  1281  find -regextype posix-extended -regex '.*(jpg|png)$'
#  1282  echo $?
#  1283  find -regextype posix-extended -regex '*(jpg|png)$'
#  1284  echo $?
#  1285  find -regextype posix-extended -regex '.*(jpg|png)$'
#  1286  echo $?
#  1287  find . -regextype posix-extended -regex '.*(jpg|png)$'
#  1288  echo $?
#  1289  find . -regextype posix-extended -regex './*(jpg|png)$'
#  1290  echo $?
#  1291  find . -regextype posix-extended -regex '.*(jpg|png)$'
#  1292  echo $?
#  1293  find . -regextype posix-extended -regex '.*'
#  1294  echo $?
#  1295  find . -regextype posix-extended -regex './*'
#  1296  echo $?
#  1297  find . -regextype posix-extended -regex '.*'
#  1298  echo $?
#  1299  find . -regextype posix-extended -regex '.*[01][34]'
#  1300  echo $?
#  1301  find . -regextype posix-extended -regex '.*[01][34]'
#  1302  echo $?
#  1303  find . -regextype posix-extended -regex '*[01][34]'
#  1304  echo $?
#  1305  find . -regextype posix-extended -regex '.[01][34]'
#  1306  echo $?
#  1307  find . -regextype posix-extended -regex '.[01][34]'
#  1308  echo $?
#  1309  compgen -cdfa -same
#  1310  compgen -cdfa -samef
#  1311  find ~ -samefile archivo-1
#  1312  echo $?
#  1313  compgen -cdfa sal
#  1314  cp saluda.sh hola.sh
#  1315  echo $?
#  1316  find . -samefile saluda.sh
#  1317  echo $?
#  1318  cp saluda.sh img/
#  1319  echo $?
#  1320  find . -samefile saluda.sh
#  1321  echo $?
#  1322  sanefile
#  1323  echo $?
#  1324  samefile
#  1325  echo $?
#  1326  ls | samefile
#  1327  echo $?
#  1328  ls | samefile
#  1329  echo $?
#  1330  ls | samefile
#  1331  echo $?
#  1332  ls | samefile
#  1333  echo $?
#  1334  ls | samefile
#  1335  echo $?
#  1336  ls -l *.sh
#  1337  echo $?
#  1338  find . -path "*CH*"
#  1339  echo $?
#  1340  find . -regextype posix-extended -regex '.[01][34]'
#  1341  echo $?
#  1342  find . -regextype posix-extended -regex '.*[01][34]'
#  1343  echo $?
#  1344  find . -regextype posix-extended -regex '.*'
#  1345  echo $?
#  1346  find . -regextype posix-extended -regex '.[12]*'
#  1347  echo $?
#  1348  find . -regextype posix-extended -regex '.*[12]*'
#  1349  echo $?
#  1350  find . -regextype posix-extended -regex '.*[12]'
#  1351  echo $?
#  1352  find . -regextype posix-extended -regex './*[12]'
#  1353  echo $?
#  1354  find . -regextype posix-extended -regex './[12]*'
#  1355  echo $?
#  1356  find . -regextype posix-extended -regex '/[12]*'
#  1357  echo $?
#  1358  find . -regextype posix-extended -regex '[12]*'
#  1359  echo $?
#  1360  find . -regextype posix-extended -regex '*'
#  1361  echo $?
#  1362  find . -regextype posix-extended -regex '.*'
#  1363  echo $?
#  1364  find . -regextype posix-extended -regex './*'
#  1365  echo $?
#  1366  find . -regextype posix-extended -regex '.\/*'
#  1367  echo $?
#  1368  find . -regextype posix-extended -regex '.\/'
#  1369  echo $?
#  1370  find . -regextype posix-extended -regex '.\'
#  1371  echo $?
#  1372  find . -regextype posix-extended -regex '.\*'
#  1373  echo $?
#  1374  find . -regextype posix-extended -regex '.\/*'
#  1375  echo $?
#  1376  find . -regextype posix-extended -regex '.\/[1]*'
#  1377  echo $?
#  1378  find . -regextype posix-extended -regex '.\/[12]*'
#  1379  echo $?
#  1380  find . -regextype posix-extended -regex '.\[12]*'
#  1381  echo $?
#  1382  find . -regextype posix-extended -regex '.[12]*'
#  1383  echo $?
#  1384  find . -regextype posix-extended -regex '.[12]'
#  1385  echo $?
#  1386  find . -regextype posix-extended -regex '.*[12]'
#  1387  echo $?
#  1388  find . -regextype posix-extended -regex '.*[12]*'
#  1389  echo $?
#  1390  find . -regextype posix-extended -regex '.*[12][3-5]*'
#  1391  echo $?
#  1392  find . -regextype posix-extended -regex '.*12*'
#  1393  echo $?
#  1394  find . -regextype posix-extended -regex '*12*'
#  1395  echo $?
#  1396  find . -regextype egrep -regex '*12*'
#  1397  echo $?
#  1398  find . -regextype egrep -regex '*'
#  1399  echo $?
#  1400  find . -regextype egrep -regex '.*'
#  1401  echo $?
#  1402  find . -regextype egrep -regex './*'
#  1403  echo $?
#  1404  find . -regextype egrep -regex './1*'
#  1405  echo $?
#  1406  find . -regextype egrep -regex '.1*'
#  1407  echo $?
#  1408  find . -regextype egrep -regex '.*'
#  1409  echo $?
#  1410  find . -regextype egrep -regex '.*.ipynb'
#  1411  echo $?
#  1412  find . -regextype egrep -regex '*.ipynb'
#  1413  echo $?
#  1414  find . -regextype egrep -regex '.*.ipynb'
#  1415  echo $?
#  1416  find . -regextype egrep -regex '.*[1][2]*.ipynb'
#  1417  echo $?
#  1418  find . -regextype egrep -regex ".*[1][2]*.ipynb"
#  1419  echo $?
#  1420  find . -regextype egrep -regex ".*.ipynb"
#  1421  echo $?
#  1422  find . -regextype egrep -regex ".*.ipynb" | sort
#  1423  echo $?
#  1424  find . -regextype  ".*.ipynb" | sort
#  1425  echo $?
#  1426  find . -regex  ".*.ipynb" | sort
#  1427  echo $?
#  1428  find . -regex  "*.ipynb" | sort
#  1429  echo $?
#  1430  find . -regex  ".*.ipynb" | sort
#  1431  echo $?
#  1432  find . -regex  ".^01*.ipynb" | sort
#  1433  echo $?
#  1434  find . -regex  ".*01*.ipynb" | sort
#  1435  echo $?
#  1436  find . -regex  ".*01?.ipynb" | sort
#  1437  echo $?
#  1438  find . -regextype posix-extended -regex '.*.ipynb'
#  1439  echo $?
#  1440  find . -regextype posix-extended -regex '.*.ipynb' | sort
#  1441  echo $?
#  1442  find . -regextype grep -regex '.*.ipynb' | sort
#  1443  echo $?
#  1444  find . -regextype grep -regex '.*.ipynb$' | sort
#  1445  echo $?
#  1446  find . -regextype grep -regex '.*ipynb$' | sort
#  1447  echo $?
#  1448  find . -regextype grep -regex '.ipynb$' | sort
#  1449  echo $?
#  1450  find . -regextype grep -regex 'ipynb$' | sort
#  1451  echo $?
#  1452  find . -regextype grep -regex '.(png|ipynb)$' | sort
#  1453  echo $?
#  1454  find . -regextype grep -regex '.*(png|ipynb)$' | sort
#  1455  echo $?
#  1456  find . -regextype grep -regex '.*png$' | sort
#  1457  echo $?
#  1458  find . -regextype grep -regex 'png$' | sort
#  1459  echo $?
#  1460  find . -regextype grep -regex '.*png$' | sort
#  1461  echo $?
#  1462  find . -regextype grep -regex '^0.*png$' | sort
#  1463  echo $?
#  1464  find . -regextype grep -regex '^0.* | sort
#  1465  find . -regextype grep -regex '^0.*' | sort
#  1466  echo $?
#  1467  find . -regextype grep -regex '.^0.*' | sort
#  1468  echo $?
#  1469  find . -regextype grep -regex '.*01_' | sort
#  1470  echo $?
#  1471  find . -regextype grep -regex '.*01_.*' | sort
#  1472  echo $?
#  1473  find . -regextype grep -regex '.*(0|2)[3-5]_.*' | sort
#  1474  echo $?
#  1475  find . -regextype grep -regex '.*(0|2)?_.*' | sort
#  1476  echo $?
#  1477  find . -regextype grep -regex '.*(0|2)_.*' | sort
#  1478  echo $?
#  1479  find . -regextype grep -regex '.*02_.*' | sort
#  1480  echo $?
#  1481  find . -regextype egrep -regex '.*\(0|2)_.*' | sort
#  1482  echo $?
#  1483  find . -regextype egrep -regex '.*(0|2)_.*' | sort
#  1484  echo $?
#  1485  find . -regextype egrep -regex '.*(0|2)({5,2})_.*' | sort
#  1486  echo $?
#  1487  find . -regextype egrep -regex '.*(0|2)(45)_.*' | sort
#  1488  echo $?
#  1489  find . -regextype egrep -regex '.*(0|2)._.*' | sort
#  1490  echo $?
#  1491  find . -regextype egrep -regex '.*(0|2)(3|4)._.*' | sort
#  1492  echo $?
#  1493  find . -regextype egrep -regex '.*(0|2)(3|4)_.*' | sort
#  1494  echo $?
#  1495  find . -regextype egrep -regex '.*(0|2)(3-8)_.*' | sort
#  1496  echo $?
#  1497  find . -regextype egrep -regex '.*png$' | sort
#  1498  echo $?
#  1499  find . -regextype egrep -regex '.(*ipynb$|*png$') | sort
#  1500  echo $?
#  1501  find . -regextype egrep -regex '.*(ipynb$|png$') | sort
#  1502  echo $?
#  1503  find . -regextype egrep -regex '.*(ipynb$|png$)' | sort
#  1504  echo $?
#  1505  find . -regextype egrep -regex '.*(sh$|png$)' | sort
#  1506  echo $?
#  1507  find . -regextype egrep -regex '.*img.*(sh$|png$)' | sort
#  1508  echo $?
#  1509  find . -regextype egrep -regex '.*(sh$|png$)' | sort
#  1510  echo $?
#  1511  find . -regextype egrep -regex '.*(0|2)(3-8)_.*' | sort
#  1512  echo $?
#  1513  find . -regextype egrep -regex '.*(0|2)(3|4|5|6|7|8)_.*' | sort
#  1514  echo $?
#  1515  find . -regextype egrep -regex '.*(0|2)(3|5|7)_.*' | sort
#  1516  echo $?
#  1517  ls -l *.sh
#  1518  echo $?
#  1519  sudo chown 1000:1000 *.sh
#  1520  echo $?
#  1521  ls -l *.sh
#  1522  echo $?
#  1523  ls -l *.sh
#  1524  echo $?
#  1525  cp saluda.sh img/
#  1526  echo $?
#  1527  find . -samefile saluda.sh
#  1528  echo $?
#  1529  ls | samefile
#  1530  echo $?
#  1531  find . -samefile saluda.sh
#  1532  echo $?
#  1533  find . -samefil saluda.sh
#  1534  echo $?
#  1535  find . -samefile ./saluda.sh
#  1536  echo $?
#  1537  find . -samefile
#  1538  echo $?
#  1539  find . -maxdepth 1 -cmin +60
#  1540  echo $?
#  1541  find . -maxdepth 1 -mmin +60
#  1542  echo $?
#  1543  find . -maxdepth 1 -mmin -60
#  1544  echo $?
#  1545  find . -maxdepth 1 -mmin -60
#  1546  echo $?
#  1547  find . -maxdepth 1 -amin -60
#  1548  echo $?
#  1549  find . -maxdepth 1 -mmin -60
#  1550  echo $?
#  1551  find . -maxdepth 1 -atime -2
#  1552  echo $?
#  1553  find . -maxdepth 1 -atime -1
#  1554  echo $?
#  1555  find . -maxdepth 2 -atime -1
#  1556  echo $?
#  1557  find . -maxdepth 1 -atime -1
#  1558  echo $?
#  1559  find . -regextype egrep -regex '.*(0|2)(3|5|7)_.*' | sort
#  1560  echo $?
#  1561  find . -regextype egrep -regex '.*(sh$|png$)' | sort
#  1562  echo $?
#  1563  sudo chown 1000:1000 *.sh
#  1564  echo $?
#  1565  ls -l *.sh
#  1566  echo $?
#  1567  cp saluda.sh img/
#  1568  echo $?
#  1569  find . -samefile
#  1570  echo $?
#  1571  find . -samefile img/saluda.sh
#  1572  echo $?
#  1573  ls | samefile
#  1574  echo $?
#  1575  find . -size +20m
#  1576  echo $?
#  1577  find . -size +20M
#  1578  echo $?
#  1579  find . -size +10M
#  1580  echo $?
#  1581  find . -size +10
#  1582  echo $?
#  1583  find . -size +10MB
#  1584  echo $?
#  1585  find . -size +10k
#  1586  echo $?
#  1587  find . -size +10K
#  1588  echo $?
#  1589  find . -size +10k
#  1590  echo $?
#  1591  find . -maxdepth 1 -size +10k
#  1592  echo $?
#  1593  find . -maxdepth 1 -size +20k
#  1594  echo $?
#  1595  type /img/cloduevel.png
#  1596  echo $?
#  1597  type /img/cloudevel.png
#  1598  echo $?
#  1599  type img/cloudevel.png
#  1600  echo $?
#  1601  type img/*
#  1602  echo $?
#  1603  file img/*
#  1604  echo $?
#  1605  find . -type d
#  1606  echo $?
#  1607  find . -maxdepth 2 -type d
#  1608  echo $?
#  1609  find . -iname '*.ipynb' -print
#  1610  echo $?
#  1611  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  1612  export PAGER=cat
#  1613  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1614  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  1615  export PAGER=cat
#  1616  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1617  whereis bash
#  1618  echo $?
#  1619  man bash
#  1620  echo $?
#  1621  bash -c ls
#  1622  echo $?
#  1623  bash -c "NUMERO=2; (NUMERO + 2)"
#  1624  echo $?
#  1625  bash -c "let NUMERO=2; (NUMERO + 2)"
#  1626  echo $?
#  1627  bash -c "let NUMERO=2; ($NUMERO + 2)"
#  1628  echo $?
#  1629  bash -c "let NUMERO=2; $($NUMERO + 2)"
#  1630  echo $?
#  1631  bash -c "let NUMERO=2; $(($NUMERO + 2))"
#  1632  echo $?
#  1633  bash -c "let NUMERO=2; (($NUMERO + 2))"
#  1634  echo $?
#  1635  bash -c "let NUMERO=2; echo (($NUMERO + 2))"
#  1636  echo $?
#  1637  bash -c "let NUMERO=2; echo $NUMERO"
#  1638  echo $?
#  1639  bash -c "let NUMERO=2; echo $NUMERO"
#  1640  echo $?
#  1641  bash -c "let NUMERO=2; echo $NUMERO;"
#  1642  echo $?
#  1643  bash -c "$[2 + 2]"
#  1644  echo $?
#  1645  bash -c "echo $[2 + 2]"
#  1646  echo $?
#  1647  bash -c "echo $[2 + 2]; let NUMERO=12; echo $[$NUMERO + 2];"
#  1648  echo $?
#  1649  bash -c "echo $[2 + 2]; NUMERO=12; echo $[$NUMERO + 2];"
#  1650  echo $?
#  1651  bash -c "echo $[2 + 2]; NUMERO=12; echo $[NUMERO + 2];"
#  1652  echo $?
#  1653  VARIABLE=1
#  1654  echo $?
#  1655  echo $VARIABLE
#  1656  echo $?
#  1657  NUMERO=12
#  1658  echo $?
#  1659  echo $[$NUMERO * 2]
#  1660  echo $?
#  1661  echo $(($NUMERO < 13))
#  1662  echo $?
#  1663  EVALUA=$(($NUMERO < 13))
#  1664  echo $EVALUA
#  1665  echo $?
#  1666  let MUL=12*5
#  1667  echo $?
#  1668  echo $MUL
#  1669  echo $?
#  1670  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO;"
#  1671  echo $?
#  1672  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo '[$NUMERO + 5]"
#  1673  echo $?
#  1674  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo '[$NUMERO + 5];"
#  1675  echo $?
#  1676  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo '[$NUMERO + 5]';"
#  1677  echo $?
#  1678  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo '(($NUMERO + 5))';"
#  1679  echo $?
#  1680  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo $(($NUMERO + 5));"
#  1681  echo $?
#  1682  #NUMERO
#  1683  echo $?
#  1684  $NUMERO
#  1685  echo $?
#  1686  echo $NUMERO
#  1687  echo $?
#  1688  bash -c echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo $(($NUMERO + 5));
#  1689  echo $?
#  1690  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo $(($NUMERO + 5));"
#  1691  echo $?
#  1692  ls $[0-1]*
#  1693  echo $?
#  1694  ls $[0-1]
#  1695  echo $?
#  1696  ls $[0-1]_*
#  1697  echo $?
#  1698  ls $[0-1]
#  1699  echo $?
#  1700  ls $[0,2]
#  1701  echo $?
#  1702  ls $[0,2]*
#  1703  echo $?
#  1704  ls $[3+2]*
#  1705  echo $?
#  1706  ls $[4 - 2]*
#  1707  echo $?
#  1708  ```read```
#  1709  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  1710  export PAGER=cat
#  1711  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1712  date
#  1713  echo $?
#  1714  man date
#  1715  echo $?
#  1716  time
#  1717  echo $?
#  1718  man time
#  1719  echo $?
#  1720  time ls
#  1721  echo $?
#  1722  time tree /
#  1723  echo $?
#  1724  man at
#  1725  echo $?
#  1726  time tree /home
#  1727  echo $?
#  1728  time du /home
#  1729  echo $?
#  1730  TZ='America/Los_Angeles' date
#  1731  echo $?
#  1732  dat %T
#  1733  echo $?
#  1734  date %T
#  1735  echo $?
#  1736  date --date %T
#  1737  echo $?
#  1738  date --date=%T
#  1739  echo $?
#  1740  date MMDDHH
#  1741  echo $?
#  1742  date +%T
#  1743  echo $?
#  1744  date +%C
#  1745  echo $?
#  1746  date +%d
#  1747  echo $?
#  1748  date +%D
#  1749  echo $?
#  1750  compgen -cdfa LI
#  1751  date -r LICENSE
#  1752  echo $?
#  1753  date --date='@2147483647'
#  1754  echo $?
#  1755  date --date='@2147383647'
#  1756  echo $?
#  1757  date --date='@2047383647'
#  1758  echo $?
#  1759  date --date='@1547383647'
#  1760  echo $?
#  1761  date --date='@1647383647'
#  1762  echo $?
#  1763  date --date='@1557383647'
#  1764  echo $?
#  1765  date --date='@1587383647'
#  1766  echo $?
#  1767  date --date='@1587383647'
#  1768  echo $?
#  1769  date -s
#  1770  echo $?
#  1771  date +%s
#  1772  echo $?
#  1773  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  1774  export PAGER=cat
#  1775  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1776  uptime
#  1777  echo $?
#  1778  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  1779  export PAGER=cat
#  1780  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  1781  echo $PATH
#  1782  echo $?
#  1783  echo $LANG
#  1784  echo $?
#  1785  echo $LANG
#  1786  echo $?
#  1787  echo $HOME
#  1788  echo $?
#  1789  ### Operadores para números.
#  1790  echo $?
#  1791  ### Operadores para enteros.
#  1792  echo $?
#  1793  $(((2 + 2)))
#  1794  echo $?
#  1795  echo $(((2 + 2)))
#  1796  echo $?
#  1797  echo $[2 + 2]
#  1798  echo $?
#  1799  bash -c "echo $[2 + 2]; VARIABLE = 2; NUMERO=12 + $VARIABLE; echo $NUMERO; echo $(($NUMERO + 5));"
#  1800  echo $?
#  1801  bash -c "echo $[2 + 2]; VAR= 2; NUMERO = 12 + $VAR; echo $NUMERO; echo $(($NUMERO + 5));"
#  1802  echo $?
#  1803  bash -c "echo $[2 + 2]; VAR=2; NUMERO=12+$VAR; echo $NUMERO; echo $(($NUMERO + 5));"
#  1804  echo $?
#  1805  bash -c "echo $[2 + 2]; VAR=2; NUMERO = 12+$VAR; echo $NUMERO; echo $(($NUMERO + 5));"
#  1806  echo $?
#  1807  bash -c "echo $[2 + 2]; VAR=2; NUMERO=[12 + $VAR]; echo $NUMERO; echo $(($NUMERO + 5));"
#  1808  echo $?
#  1809  bash -c "echo $[2 + 2]; VAR=2; NUMERO=$[12 + $VAR]; echo $NUMERO; echo $(($NUMERO + 5));"
#  1810  echo $?
#  1811  bash -c "echo $[2 + 2]; VAR=2; NUMERO=$((12 + $VAR)); echo $NUMERO; echo $(($NUMERO + 5));"
#  1812  echo $?
#  1813  bash -c "echo $[2 + 2]; VAR=2; NUMERO=[12 + $VAR]; echo $NUMERO; echo $(($NUMERO + 5));"
#  1814  echo $?
#  1815  NUMERO=12
#  1816  echo $?
#  1817  echo $[$NUMERO * 2]
#  1818  echo $?
#  1819  echo $(($NUMERO < 13))
#  1820  echo $?
#  1821  EVALUA=$(($NUMERO < 13))
#  1822  echo $EVALUA
#  1823  echo $?
#  1824  let MUL=12*5
#  1825  echo $?
#  1826  echo $MUL
#  1827  echo $?
#  1828  bash -c "echo $[2 + 2]; VAR=2; NUMERO = [12 + $VAR]; echo $NUMERO; echo $(($NUMERO + 5));"
#  1829  echo $?
#  1830  bash -c "echo $[2 + 2]; NUMERO = [12 + $VAR]; echo $NUMERO; echo $(($NUMERO + 5));"
#  1831  echo $?
#  1832  bash -c "echo $[2 + 2]; NUMERO = 12; echo $NUMERO; echo $(($NUMERO + 5));"
#  1833  echo $?
#  1834  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo $(($NUMERO + 5));"
#  1835  echo $?
#  1836  bash -c "echo $[2 + 2]; NUMERO=12; VAR=[NUMERO + 5]; echo $NUMERO; echo $(($NUMERO + 5));"
#  1837  echo $?
#  1838  bash -c "echo $[2 + 2]; NUMERO=12; VAR=[NUMERO+5]; echo $NUMERO; echo $(($NUMERO + 5));"
#  1839  echo $?
#  1840  bash -c "echo $[2 + 2]; NUMERO=12; VAR=[NUMERO+5]; echo $NUMERO; echo $(($VAR + 5));"
#  1841  echo $?
#  1842  bash -c "echo $[2 + 2]; NUMERO=12; VAR=[$NUMERO+5]; echo $NUMERO; echo $(($VAR + 5));"
#  1843  echo $?
#  1844  bash -c "echo $[2 + 2]; NUMERO=12; VAR=$[$NUMERO+5]; echo $NUMERO; echo $(($VAR + 5));"
#  1845  echo $?
#  1846  bash -c "echo $[2 + 2]; NUMERO=12; VAR=$[$NUMERO+5]; echo $NUMERO; echo $$VAR;"
#  1847  echo $?
#  1848  bash -c "echo $[2 + 2]; NUMERO=12; VAR=$[$NUMERO+5]; echo $NUMERO; echo $VAR;"
#  1849  echo $?
#  1850  bash -c "echo $[2 + 2]; NUMERO=12; VAR=$[$NUMERO + 5]; echo $NUMERO; echo $VAR;"
#  1851  echo $?
#  1852  bash -c "echo $[2 + 2]; NUMERO=12; VAR=[$NUMERO + 5]; echo $NUMERO; echo $VAR;"
#  1853  echo $?
#  1854  bash -c "echo $[2 + 2]; NUMERO=12; VAR=(($NUMERO + 5)); echo $NUMERO; echo $VAR;"
#  1855  echo $?
#  1856  bash -c "echo $[2 + 2]; NUMERO=12; VAR=($NUMERO + 5); echo $NUMERO; echo $VAR;"
#  1857  echo $?
#  1858  bash -c "echo $[2 + 2]; NUMERO=12; VAR=$NUMERO; echo $NUMERO; echo $VAR;"
#  1859  echo $?
#  1860  bash -c "echo $[2 + 2]; NUMERO=12; VAR=15; echo $NUMERO; echo $VAR;"
#  1861  echo $?
#  1862  bash -c "echo $[2 + 2]; NUMERO=12; VAR=15; echo $NUMERO; echo $NUMERO;"
#  1863  echo $?
#  1864  bash -c "echo $[2 + 2]; NUMERO=12; VAR=15; echo $NUMERO; echo $(($NUMERO + 15));"
#  1865  echo $?
#  1866  bash -c "echo $[2 + 2]; NUMERO=12; echo $NUMERO; echo $(($NUMERO + 15));"
#  1867  echo $?
#  1868  echo Hola, Mundo.
#  1869  echo $?
#  1870  echo 'Hola, Mundo.'
#  1871  echo $?
#  1872  echo 2 + 5
#  1873  echo $?
#  1874  echo $[2 + 2]
#  1875  echo $?
#  1876  echo $((2 + 2))
#  1877  echo $?
#  1878  ls $[4 - 2]*
#  1879  echo $?
#  1880  echo $HOME
#  1881  echo $?
#  1882  echo $[2 + 2]
#  1883  echo $?
#  1884  VARIABLE=1
#  1885  echo $?
#  1886  echo $VARIABLE
#  1887  echo $?
#  1888  EVALUA=$(($NUMERO < 13))
#  1889  echo $EVALUA
#  1890  echo $?
#  1891  echo $(($NUMERO > 13))
#  1892  echo $?
#  1893  echo $(($NUMERO <13))
#  1894  echo $?
#  1895  echo $(($NUMERO < 13))
#  1896  echo $?
#  1897  echo $[1 < 2]
#  1898  echo $?
#  1899  ecgo $[1 -lt 2]
#  1900  echo $?
#  1901  echo $[1 -lt 2]
#  1902  echo $?
#  1903  echo $[1 -lt 2]
#  1904  echo $?
#  1905  echo $[1 -lt 2]
#  1906  echo $?
#  1907  echo $((1 -lt 2))
#  1908  echo $?
#  1909  echo $(($X -lt $Y))
#  1910  echo $?
#  1911  echo $(($X lt $Y))
#  1912  echo $?
#  1913  echo $(($X -lt $Y))
#  1914  echo $?
#  1915  if [2 -lt 3]; then echo SI; else echo No; fi
#  1916  echo $?
#  1917  if [2 lt 3]; then echo SI; else echo No; fi
#  1918  echo $?
#  1919  if [$2 lt $3]; then echo SI; else echo No; fi
#  1920  echo $?
#  1921  if [$X lt $Y]; then echo SI; else echo No; fi
#  1922  echo $?
#  1923  if ["$X" lt "$Y"]; then echo SI; else echo No; fi
#  1924  echo $?
#  1925  if ["$X" -lt "$Y"]; then echo SI; else echo No; fi
#  1926  echo $?
#  1927  if ["$X" >= "$Y"]; then echo SI; else echo No; fi
#  1928  echo $?
#  1929  if ["$X" > "$Y"]; then echo SI; else echo No; fi
#  1930  echo $?
#  1931  if [ "$X" > "$Y" ]; then echo SI; else echo No; fi
#  1932  echo $?
#  1933  if [ 2 > "$Y" ]; then echo SI; else echo No; fi
#  1934  echo $?
#  1935  if [ 15 > "$Y" ]; then echo SI; else echo No; fi
#  1936  echo $?
#  1937  if [ 1 > "$Y" ]; then echo SI; else echo No; fi
#  1938  echo $?
#  1939  if [ 1 -lt "$Y" ]; then echo SI; else echo No; fi
#  1940  echo $?
#  1941  if [ 13 -lt "$Y" ]; then echo SI; else echo No; fi
#  1942  echo $?
#  1943  if [ 13 < "$Y" ]; then echo SI; else echo No; fi
#  1944  echo $?
#  1945  if [ 13 lt "$Y" ]; then echo SI; else echo No; fi
#  1946  echo $?
#  1947  if [ 13 -lt "$Y" ]; then echo SI; else echo No; fi
#  1948  echo $?
#  1949  if [ 13 -gt "$Y" ]; then echo SI; else echo No; fi
#  1950  echo $?
#  1951  echo $[ 1 -gt 2 ]
#  1952  echo $?
#  1953  echo $[2 + 2]
#  1954  echo $?
#  1955  echo $[14 / 3]
#  1956  echo $?
#  1957  echo $[14 % 3]
#  1958  echo $?
#  1959  echo $[ 13 -gt "$Y" ]
#  1960  echo $?
#  1961  echo $[14 != 3]
#  1962  echo $?
#  1963  echo $[14 == 3]
#  1964  echo $?
#  1965  let MUL=[12*$NUMERO]
#  1966  echo $?
#  1967  let MUL=$[12*$NUMERO]
#  1968  echo $?
#  1969  echo $MUL
#  1970  echo $?
#  1971  MUL=$[12*$NUMERO]
#  1972  echo $?
#  1973  echo $MUL
#  1974  echo $?
#  1975  MUL=[12*$NUMERO]
#  1976  echo $?
#  1977  echo $MUL
#  1978  echo $?
#  1979  MUL=$[12*$NUMERO]
#  1980  echo $?
#  1981  bash -c "echo $[2 + 2]; NUMERO=12; MUL=${12*$NUMERO}; echo $NUMERO; echo $(($MUL + 15));"
#  1982  echo $?
#  1983  bash -c "echo $[2 + 2]; NUMERO=12; MUL=$[2*$NUMERO]; echo $NUMERO; echo $(($MUL + 15));"
#  1984  echo $?
#  1985  bash -c "echo $[2 + 2]; NUMERO=12; MUL=$[2*$NUMERO]; echo $NUMERO; echo $($MUL);"
#  1986  echo $?
#  1987  bash -c "echo $[2 + 2]; NUMERO=12; MUL=$[2*$NUMERO]; echo $NUMERO; echo $$MUL;"
#  1988  echo $?
#  1989  bash -c "echo $[2 + 2]; NUMERO=12; MUL=$[2*$NUMERO]; echo $NUMERO; echo $MUL;"
#  1990  echo $?
#  1991  bash -c "echo $[2 + 2]; NUMERO=12; MULT=$[2 * $NUMERO]; echo $NUMERO; echo $MUL;"
#  1992  echo $?
#  1993  bash -c "echo $[2 + 2]; NUMERO=12; MULT=$[2 * $NUMERO]; echo $NUMERO; echo $MULT;"
#  1994  echo $?
#  1995  bash -c "echo $[2 + 2]; NUMERO=12; let MULT=$[2 * $NUMERO]; echo $NUMERO; echo $MULT;"
#  1996  echo $?
#  1997  bash -c "echo $[2 + 2]; NUM=12; let MULT=$[2 * $NUMERO]; echo $NUMERO; echo $MULT;"
#  1998  echo $?
#  1999  bash -c "echo $[2 + 2]; NUM=12; MULT=$[2 * $NUMERO]; echo $NUMERO; echo $MULT;"
#  2000  echo $?
#  2001  PS1='[PEXP\[\]ECT_PROMPT>' PS2='[PEXP\[\]ECT_PROMPT+' PROMPT_COMMAND=''
#  2002  export PAGER=cat
#  2003  display () {     TMPFILE=$(mktemp ${TMPDIR-/tmp}/bash_kernel.XXXXXXXXXX);     cat > $TMPFILE;     echo "bash_kernel: saved image data to: $TMPFILE" >&2; }
#  2004  El cmando ```alias```.
#  2005  echo $?
#  2006  El comando ```alias```.
#  2007  echo $?
#  2008  man source
#  2009  echo $?
#  2010  man source
#  2011  echo $?
#  2012  which source
#  2013  echo $?
#  2014  which alias
#  2015  echo $?
#  2016  ## La historia.
#  2017  echo $?
#  2018  !
#  2019  echo $?
#  2020  history

# %%
history 3
# Out:
#  2024  history -3
#  2025  echo $?
#  2026  history 3

# %% [markdown]
# Recreación de comandos.

# %%
ls
# Out:
#  01_introduccion.ipynb
#  02_sistemas_de_computo.ipynb
#  03_la_linea_de_comandos.ipynb
#  04_directorios_y_archivos.ipynb
#  05_jerarquía_de_directorios.ipynb
#  06_flujos_de_texto_filtros_y_pipes.ipynb
#  07_expresiones_regulares_y_grep.ipynb
#  08_introduccion_a_vim.ipynb
#  09_usuarios_y_grupos.ipynb
#  10_permisos_y_propietarios_de_archivos.ipynb
#  11_procesos_trabajos_y_daemons.ipynb
#  12_find_y_xargs.ipynb
#  13_introduccion_a_bash_scripting.ipynb
#  14_entorno_del_sell.ipynb
#  15_fechas_horas_y_temporizadores.ipynb
#  16_inicio_y_apagado_del_sistema.ipynb
#  17_kernel_modulos_y_dispositivos.ipynb
#  18_volumenes_y_particiones.ipynb
#  19_gestion_de_servicios_con_systemd.ipynb
#  2
#  20_chroot_y_contenedores.ipynb
#  21_introduccion_a_redes_basicas.ipynb
#  22_paquetes_de_software.ipynb
#  23_sesiones_remotas_y_transmision_de_datos.ipynb
#  24_virtualizacion.ipynb
#  25_seguridad_basica.ipynb
#  2]
# '='
#  LICENSE
#  README.md
#  data
#  hola.sh
#  img
#  saluda.sh

# %%
history 4
# Out:
#  2033  compgen -cdfa hist
#  2034  history
#  2035  echo $?
#  2036  history 4

# %%
ls -l
# Out:
# total 2336
# -rw-r--r-- 1 oi oi   10956 May 28 02:57  01_introduccion.ipynb
# -rw-r--r-- 1 oi oi   14891 May 28 02:57  02_sistemas_de_computo.ipynb
# -rw-r--r-- 1 oi oi   12603 May 28 02:57  03_la_linea_de_comandos.ipynb
# -rw-r--r-- 1 oi oi   60830 Jun  2 19:59  04_directorios_y_archivos.ipynb
# -rw-r--r-- 1 oi oi    9741 Jun  2 20:01  05_jerarquía_de_directorios.ipynb
# -rw-r--r-- 1 oi oi   45839 Jun  3 17:53  06_flujos_de_texto_filtros_y_pipes.ipynb
# -rw-r--r-- 1 oi oi    6634 Jun  5 03:15  07_expresiones_regulares_y_grep.ipynb
# -rw-r--r-- 1 oi oi    8033 Jun  2 16:34  08_introduccion_a_vim.ipynb
# -rw-r--r-- 1 oi oi   37130 Jun  3 17:45  09_usuarios_y_grupos.ipynb
# -rw-r--r-- 1 oi oi    7117 Jun  3 15:40  10_permisos_y_propietarios_de_archivos.ipynb
# -rw-r--r-- 1 oi oi   19191 Jun  5 04:15  11_procesos_trabajos_y_daemons.ipynb
# -rw-r--r-- 1 oi oi   10646 Jun  5 03:13  12_find_y_xargs.ipynb
# -rw-r--r-- 1 oi oi   18160 Jun  5 06:00  13_introduccion_a_bash_scripting.ipynb
# -rw-r--r-- 1 oi oi   47158 Jun  5 06:15  14_entorno_del_sell.ipynb
# -rw-r--r-- 1 oi oi 1914800 Jun  5 04:15  15_fechas_horas_y_temporizadores.ipynb
# -rw-r--r-- 1 oi oi    6245 May 30 21:36  16_inicio_y_apagado_del_sistema.ipynb
# -rw-r--r-- 1 oi oi    8226 May 30 21:36  17_kernel_modulos_y_dispositivos.ipynb
# -rw-r--r-- 1 oi oi   12537 May 30 21:36  18_volumenes_y_particiones.ipynb
# -rw-r--r-- 1 oi oi    5924 May 30 21:36  19_gestion_de_servicios_con_systemd.ipynb
# -rw-r--r-- 1 oi oi       0 Jun  5 04:52  2
# -rw-r--r-- 1 oi oi    4174 May 30 21:36  20_chroot_y_contenedores.ipynb
# -rw-r--r-- 1 oi oi   13754 May 30 21:36  21_introduccion_a_redes_basicas.ipynb
# -rw-r--r-- 1 oi oi   17268 May 30 21:36  22_paquetes_de_software.ipynb
# -rw-r--r-- 1 oi oi    6275 May 30 21:36  23_sesiones_remotas_y_transmision_de_datos.ipynb
# -rw-r--r-- 1 oi oi   10385 May 30 21:36  24_virtualizacion.ipynb
# -rw-r--r-- 1 oi oi    2885 May 30 21:36  25_seguridad_basica.ipynb
# -rw-r--r-- 1 oi oi       0 Jun  5 04:51  2]
# -rw-r--r-- 1 oi oi       0 Jun  5 04:51 '='
# -rw-r--r-- 1 oi oi    1064 May 30 21:36  LICENSE
# -rw-r--r-- 1 oi oi    1133 May 28 02:57  README.md
# drwxr-xr-x 3 oi oi    4096 May 30 21:36  data
# -rwxr-xr-x 1 oi oi      28 Jun  5 02:24  hola.sh
# drwxr-xr-x 6 oi oi    4096 Jun  5 02:58  img
# -rwxr-xr-x 1 oi oi      28 Jun  5 01:41  saluda.sh

# %%
echo Hola
# Out:
# Hola

# %%
!! Mundo
# Out:
# echo $? Mundo
# 0 Mundo

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2019.</p>
